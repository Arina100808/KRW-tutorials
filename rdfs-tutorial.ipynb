# %% [markdown]
# # Knowledge Representation on the Web -- RDFS tutorial
#
# Here we'll learn the basics of RDFS (RDF Schema) and how to perform basic RDFS reasoning with rdflib (documentation [here](https://rdflib.readthedocs.io/en/stable/)) and owlrl (documentation [here](https://owl-rl.readthedocs.io/en/latest/)).

# %% [markdown]
# ## Imports
#
# owlrl is a library implementing basic RDFS and OWL reasoning on top of rdflib. We'll install and import its relevant symbols.

# %%
import sys
# !{sys.executable} -m pip install rdflib owlrl

from rdflib import Graph, RDFS, RDF, URIRef, Namespace, Literal
from owlrl import DeductiveClosure, RDFS_Semantics
# Out:
# Requirement already satisfied: rdflib in /Users/arina/.pyenv/versions/3.10.13/envs/krwvenv/lib/python3.10/site-packages (7.0.0)
# Requirement already satisfied: owlrl in /Users/arina/.pyenv/versions/3.10.13/envs/krwvenv/lib/python3.10/site-packages (6.0.2)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /Users/arina/.pyenv/versions/3.10.13/envs/krwvenv/lib/python3.10/site-packages (from rdflib) (3.1.1)
# Requirement already satisfied: isodate<0.7.0,>=0.6.0 in /Users/arina/.pyenv/versions/3.10.13/envs/krwvenv/lib/python3.10/site-packages (from rdflib) (0.6.1)
# Requirement already satisfied: six in /Users/arina/.pyenv/versions/3.10.13/envs/krwvenv/lib/python3.10/site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: python3.10 -m pip install --upgrade pip

# %% [markdown]
# ## Loading RDFS graphs
#
# Your file `yourRDF.ttl` already contains a basic Knowledge Graph in RDF with some RDFS semantics
#
# First, we are going to add some RDFS semantics, and inspect the graph as-is; this is also called the "asserted graph"
#
# **Exercise 1**
# 1. load yourRDF graph
# 2. add additional triples using the RDFS semantics: have a look [here](https://www.w3.org/TR/rdf-schema/), and use domain and range, subPropertyOf, and Class, to say more about the instances in your graph
# 3. print the classes in your graph
# 4. print the properties of a specific class in yourRDF graph
# 5. print all instances in yourRDF graph (all objects that have a type)
# 6. explain what constitutes a vocabulary in RDF

# %%
def check_graph(graph):
    ''' Additional function to check if graph is empty and print graph's length.'''
    # Loop through each triple in the graph (subj, pred, obj)
    for subj, pred, obj in graph:
        # Check if there is at least one triple in the Graph
        if (subj, pred, obj) not in graph:
           print("There are no triples in the Graph")
    # Print the number of "triples" in the Graph
    print(f"The graph has {len(graph)} statements.")

# %%
# define graph
graph = Graph()
graph.parse("./data/yourRDF.ttl")
# define example namespace
SOLAR = Namespace("http://example.org/solarsystem/")

# %%
# Add triples using store's add method.
graph.add((SOLAR.CelestialBody, RDF.type, RDFS.Class))
graph.add((SOLAR.satelliteOf, RDFS.domain, SOLAR.Satellite))
graph.add((SOLAR.satelliteOf, RDFS.range, SOLAR.CelestialBody))
graph.add((SOLAR.naturalSatelliteOf, RDFS.subPropertyOf, SOLAR.satelliteOf))
graph.add((SOLAR.naturalSatelliteOf, RDFS.domain, SOLAR.NaturalSatellite))
# Out:
# <Graph identifier=Nc91a0290fbf1422183b1e7b194c42f69 (<class 'rdflib.graph.Graph'>)>

# %%
print("Total # of statements:")
check_graph(graph)
print("\n")
print(graph.serialize(format="turtle"))
# Out:
# Total # of statements:
# The graph has 15 statements.
#
#
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix solar: <http://example.org/solarsystem/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# solar:CelestialBody a rdfs:Class .
#
# solar:Moon a solar:NaturalSatellite ;
#     solar:naturalSatelliteOf solar:Earth .
#
# solar:Sun a solar:Star ;
#     rdfs:label "Sun" ;
#     solar:hasRadius 695000 .
#
# solar:naturalSatelliteOf rdfs:domain solar:NaturalSatellite ;
#     rdfs:subPropertyOf solar:satelliteOf .
#
# solar:Earth a solar:Planet .
#
# solar:Planet rdfs:subClassOf solar:CelestialBody .
#
# solar:Star rdfs:subClassOf solar:CelestialBody .
#
# solar:satelliteOf rdfs:domain solar:Satellite ;
#     rdfs:range solar:CelestialBody .
#
# solar:NaturalSatellite rdfs:subClassOf solar:Satellite .
#
# solar:Satellite rdfs:subClassOf solar:CelestialBody .

# %%
graph.serialize(destination="./data/yourRDF.ttl")
# Out:
# <Graph identifier=Nc91a0290fbf1422183b1e7b194c42f69 (<class 'rdflib.graph.Graph'>)>

# %%
# print classes
print("Classes:")
classes = set()
for subj, pred, obj in graph.triples((None, RDFS.subClassOf, None)):
    if obj not in classes:
        print(obj)
        classes.add(obj)
    if subj not in classes:
        print(subj)
        classes.add(subj)
# Out:
# Classes:
# http://example.org/solarsystem/CelestialBody
# http://example.org/solarsystem/Planet
# http://example.org/solarsystem/Star
# http://example.org/solarsystem/Satellite
# http://example.org/solarsystem/NaturalSatellite

# %%
# print properties
print("Properties of the NaturalSatellite class:")
for subj, pred, obj in graph.triples((None, RDF.type, SOLAR.NaturalSatellite)):
    for s, p, o in graph.triples((subj, None, None)):
        print(p)
# Out:
# Properties of the NaturalSatellite class:
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://example.org/solarsystem/naturalSatelliteOf

# %%
# print all instances
print("Instances:")
comment = ""
for subj, pred, obj in graph.triples((None, RDF.type, None)):
    if obj == RDFS.Class:
        comment = " - class"
    print(f"{subj}{comment}")
    comment = ""
# Out:
# Instances:
# http://example.org/solarsystem/CelestialBody - class
# http://example.org/solarsystem/Moon
# http://example.org/solarsystem/Sun
# http://example.org/solarsystem/Earth

# %% [markdown]
# In RDF, a **vocabulary** on the Semantic Web consists of a set of terms or "special keywords" that define concepts and relationships to represent a specific domain. These terms include classes, subclasses, properties, and instances, allowing for the description and categorization of resources. For instance, one can specify that a resource is a class, define relationships between classes (such as subclass relationships), and indicate instances of those classes using RDF statements.

# %% [markdown]
# ## RDFS inferencing
#
# The inference engine in owlrl is triggered by `DeductiveClosure`, which computes the closure of the graph. This requires us to specify under which semantic regime we want to perform the inference (e.g. what kind of rules under the RDFS, OWL, etc. semantics we want the reasoner to produce derivations on). For RDFS semantics we use `RDFS_Semantics` as parameter. See extra options [here](https://owl-rl.readthedocs.io/en/latest/stubs/owlrl.html#module-owlrl)
#
#
# **Exercise 2**
# 1. expand the graph through RDFS semantics inference
# 2. print how many triples the new graph has
# 3. print out the triples in your new graph and inspect them.

# %%
# 1. expand the graph through RDFS semantics inference
expanded = Graph()
expanded.parse("./data/yourRDF.ttl")
DeductiveClosure(RDFS_Semantics).expand(expanded)

# %%
# 2. print how many triples the new graph has
print("Total # of statements:")
check_graph(expanded)
# Out:
# Total # of statements:
# The graph has 58 statements.

# %%
# 3. print out the triples in your new graph and inspect them. 
resource = list()
for subj, pred, obj in expanded:
    if obj != RDFS.Resource:
        print(f"({subj.n3(expanded.namespace_manager)}, {pred.n3(expanded.namespace_manager)}, {obj.n3(expanded.namespace_manager)})")
    else:
        resource.append((subj, pred, obj))
print("\n")
for subj, pred, obj in resource:
    print(f"({subj.n3(expanded.namespace_manager)}, {pred.n3(expanded.namespace_manager)}, {obj.n3(expanded.namespace_manager)})")
# Out:
# (solar:Satellite, rdfs:subClassOf, solar:CelestialBody)
# (solar:NaturalSatellite, rdfs:subClassOf, solar:CelestialBody)
# (solar:Moon, rdf:type, solar:NaturalSatellite)
# (solar:Sun, rdf:type, solar:CelestialBody)
# (rdfs:subClassOf, rdf:type, rdf:Property)
# (rdfs:domain, rdf:type, rdf:Property)
# (solar:naturalSatelliteOf, rdfs:domain, solar:NaturalSatellite)
# (rdfs:subClassOf, rdfs:subPropertyOf, rdfs:subClassOf)
# (solar:CelestialBody, rdf:type, rdfs:Class)
# (solar:Sun, solar:hasRadius, "695000"^^xsd:integer)
# (solar:hasRadius, rdfs:subPropertyOf, solar:hasRadius)
# (solar:satelliteOf, rdfs:subPropertyOf, solar:satelliteOf)
# (solar:naturalSatelliteOf, rdfs:subPropertyOf, solar:satelliteOf)
# (solar:Moon, rdf:type, solar:CelestialBody)
# (rdfs:domain, rdfs:subPropertyOf, rdfs:domain)
# (solar:Earth, rdf:type, solar:CelestialBody)
# (solar:NaturalSatellite, rdfs:subClassOf, solar:Satellite)
# (rdf:type, rdf:type, rdf:Property)
# (solar:Earth, rdf:type, solar:Planet)
# (rdfs:range, rdf:type, rdf:Property)
# (solar:Star, rdfs:subClassOf, solar:CelestialBody)
# (rdfs:subPropertyOf, rdfs:subPropertyOf, rdfs:subPropertyOf)
# (solar:Sun, rdfs:label, "Sun")
# (solar:satelliteOf, rdfs:domain, solar:Satellite)
# (solar:Moon, solar:naturalSatelliteOf, solar:Earth)
# (rdfs:label, rdfs:subPropertyOf, rdfs:label)
# (solar:Moon, rdf:type, solar:Satellite)
# (solar:CelestialBody, rdfs:subClassOf, solar:CelestialBody)
# (solar:satelliteOf, rdfs:range, solar:CelestialBody)
# (solar:Sun, rdf:type, solar:Star)
# (solar:hasRadius, rdf:type, rdf:Property)
# (solar:Moon, solar:satelliteOf, solar:Earth)
# (rdfs:range, rdfs:subPropertyOf, rdfs:range)
# (solar:naturalSatelliteOf, rdfs:subPropertyOf, solar:naturalSatelliteOf)
# (solar:Planet, rdfs:subClassOf, solar:CelestialBody)
# (solar:satelliteOf, rdf:type, rdf:Property)
# (solar:naturalSatelliteOf, rdf:type, rdf:Property)
# (rdfs:subPropertyOf, rdf:type, rdf:Property)
# (rdf:type, rdfs:subPropertyOf, rdf:type)
# (rdfs:label, rdf:type, rdf:Property)
#
#
# (solar:naturalSatelliteOf, rdf:type, rdfs:Resource)
# (solar:satelliteOf, rdf:type, rdfs:Resource)
# (solar:CelestialBody, rdfs:subClassOf, rdfs:Resource)
# ("695000"^^xsd:integer, rdf:type, rdfs:Resource)
# (rdfs:Class, rdf:type, rdfs:Resource)
# (solar:Planet, rdfs:subClassOf, rdfs:Resource)
# (solar:Star, rdf:type, rdfs:Resource)
# ("Sun", rdf:type, rdfs:Resource)
# (solar:Satellite, rdfs:subClassOf, rdfs:Resource)
# (solar:NaturalSatellite, rdfs:subClassOf, rdfs:Resource)
# (solar:Sun, rdf:type, rdfs:Resource)
# (solar:CelestialBody, rdf:type, rdfs:Resource)
# (solar:Moon, rdf:type, rdfs:Resource)
# (solar:Satellite, rdf:type, rdfs:Resource)
# (solar:Earth, rdf:type, rdfs:Resource)
# (solar:Planet, rdf:type, rdfs:Resource)
# (solar:NaturalSatellite, rdf:type, rdfs:Resource)
# (solar:Star, rdfs:subClassOf, rdfs:Resource)

# %% [markdown]
# ## The explicit (asserted) graph vs the implicit (derived) graph, and RDF entailment
#
# Asserted triples are those that are explicitly stated, while derived or inferred triples are those that are implicitly stated through the semantics of RDFS.
#
# **Exercise 3**
#
# 1. Write here code to generate a graph that contains **RDFS derived triples only** from yourRDF Knowledge Graph, not the asserted ones. See a clue on rdflib graph algebra [here](https://rdflib.readthedocs.io/en/stable/merging.html)
# 2. have a look at the inferred graph. Based on the RDFS semantics, explain for each triple the rule that was used to generate it.
# 3. Explain the concept RDF entailment, and the types of entailment RDFS can produce

# %%
derived = expanded - graph
derived.namespace_manager.bind('solar', SOLAR)
print("Total # of statements:")
check_graph(derived)
print("\n")
resource = list()
property = list()
for subj, pred, obj in derived:
    if obj not in [RDFS.Resource, RDF.Property]:
        print(f"({subj.n3(derived.namespace_manager)}, {pred.n3(derived.namespace_manager)}, {obj.n3(derived.namespace_manager)})")
    elif obj == RDFS.Resource:
        resource.append((subj, pred, obj))
    elif obj == RDF.Property:
        property.append((subj, pred, obj))
for subj, pred, obj in resource:
    print(f"({subj.n3(derived.namespace_manager)}, {pred.n3(derived.namespace_manager)}, {obj.n3(derived.namespace_manager)})")
for subj, pred, obj in property:
    print(f"({subj.n3(derived.namespace_manager)}, {pred.n3(derived.namespace_manager)}, {obj.n3(derived.namespace_manager)})")
# Out:
# Total # of statements:
# The graph has 43 statements.
#
#
# (solar:NaturalSatellite, rdfs:subClassOf, solar:CelestialBody)
# (solar:Sun, rdf:type, solar:CelestialBody)
# (solar:hasRadius, rdfs:subPropertyOf, solar:hasRadius)
# (solar:satelliteOf, rdfs:subPropertyOf, solar:satelliteOf)
# (solar:Moon, rdf:type, solar:CelestialBody)
# (rdfs:domain, rdfs:subPropertyOf, rdfs:domain)
# (solar:Earth, rdf:type, solar:CelestialBody)
# (rdf:type, rdfs:subPropertyOf, rdf:type)
# (rdfs:subPropertyOf, rdfs:subPropertyOf, rdfs:subPropertyOf)
# (rdfs:label, rdfs:subPropertyOf, rdfs:label)
# (solar:Moon, rdf:type, solar:Satellite)
# (solar:CelestialBody, rdfs:subClassOf, solar:CelestialBody)
# (solar:Moon, solar:satelliteOf, solar:Earth)
# (rdfs:range, rdfs:subPropertyOf, rdfs:range)
# (solar:naturalSatelliteOf, rdfs:subPropertyOf, solar:naturalSatelliteOf)
# (rdfs:subClassOf, rdfs:subPropertyOf, rdfs:subClassOf)
# (solar:naturalSatelliteOf, rdf:type, rdfs:Resource)
# (solar:satelliteOf, rdf:type, rdfs:Resource)
# (solar:CelestialBody, rdfs:subClassOf, rdfs:Resource)
# ("695000"^^xsd:integer, rdf:type, rdfs:Resource)
# (rdfs:Class, rdf:type, rdfs:Resource)
# (solar:Planet, rdfs:subClassOf, rdfs:Resource)
# (solar:Star, rdf:type, rdfs:Resource)
# ("Sun", rdf:type, rdfs:Resource)
# (solar:Satellite, rdfs:subClassOf, rdfs:Resource)
# (solar:NaturalSatellite, rdfs:subClassOf, rdfs:Resource)
# (solar:Sun, rdf:type, rdfs:Resource)
# (solar:CelestialBody, rdf:type, rdfs:Resource)
# (solar:Moon, rdf:type, rdfs:Resource)
# (solar:Satellite, rdf:type, rdfs:Resource)
# (solar:Earth, rdf:type, rdfs:Resource)
# (solar:Planet, rdf:type, rdfs:Resource)
# (solar:NaturalSatellite, rdf:type, rdfs:Resource)
# (solar:Star, rdfs:subClassOf, rdfs:Resource)
# (rdfs:domain, rdf:type, rdf:Property)
# (rdfs:subClassOf, rdf:type, rdf:Property)
# (rdf:type, rdf:type, rdf:Property)
# (rdfs:range, rdf:type, rdf:Property)
# (solar:naturalSatelliteOf, rdf:type, rdf:Property)
# (solar:hasRadius, rdf:type, rdf:Property)
# (rdfs:subPropertyOf, rdf:type, rdf:Property)
# (solar:satelliteOf, rdf:type, rdf:Property)
# (rdfs:label, rdf:type, rdf:Property)

# %% [markdown]
# ### [**RDFS entailment rules:**](https://www.w3.org/TR/rdf-mt/#rules)

# %% [markdown]
# * **(S, P, O) => (P, rdf:type, rdf:Property)**

# %%
for subj, pred, obj in property:
    print(f"({subj.n3(derived.namespace_manager)}, {pred.n3(derived.namespace_manager)}, {obj.n3(derived.namespace_manager)})")
# Out:
# (rdfs:domain, rdf:type, rdf:Property)
# (rdfs:subClassOf, rdf:type, rdf:Property)
# (rdf:type, rdf:type, rdf:Property)
# (rdfs:range, rdf:type, rdf:Property)
# (solar:naturalSatelliteOf, rdf:type, rdf:Property)
# (solar:hasRadius, rdf:type, rdf:Property)
# (rdfs:subPropertyOf, rdf:type, rdf:Property)
# (solar:satelliteOf, rdf:type, rdf:Property)
# (rdfs:label, rdf:type, rdf:Property)

# %% [markdown]
# * **(S, P, O) => (S, rdf:type, rdfs:Resource)**
# * **(S, P, O) => (O, rdf:type, rdfs:Resource)**
# * **(S, rdf:type, rdfs:Class) => (S, rdfs:subClassOf rdfs:Resource)**

# %%
for subj, pred, obj in resource:
    print(f"({subj.n3(derived.namespace_manager)}, {pred.n3(derived.namespace_manager)}, {obj.n3(derived.namespace_manager)})")
# Out:
# (solar:naturalSatelliteOf, rdf:type, rdfs:Resource)
# (solar:satelliteOf, rdf:type, rdfs:Resource)
# (solar:CelestialBody, rdfs:subClassOf, rdfs:Resource)
# ("695000"^^xsd:integer, rdf:type, rdfs:Resource)
# (rdfs:Class, rdf:type, rdfs:Resource)
# (solar:Planet, rdfs:subClassOf, rdfs:Resource)
# (solar:Star, rdf:type, rdfs:Resource)
# ("Sun", rdf:type, rdfs:Resource)
# (solar:Satellite, rdfs:subClassOf, rdfs:Resource)
# (solar:NaturalSatellite, rdfs:subClassOf, rdfs:Resource)
# (solar:Sun, rdf:type, rdfs:Resource)
# (solar:CelestialBody, rdf:type, rdfs:Resource)
# (solar:Moon, rdf:type, rdfs:Resource)
# (solar:Satellite, rdf:type, rdfs:Resource)
# (solar:Earth, rdf:type, rdfs:Resource)
# (solar:Planet, rdf:type, rdfs:Resource)
# (solar:NaturalSatellite, rdf:type, rdfs:Resource)
# (solar:Star, rdfs:subClassOf, rdfs:Resource)

# %% [markdown]
# * **(solar:NaturalSatellite, rdfs:subClassOf, solar:CelestialBody)**
# because:
#     * (solar:NaturalSatellite, rdfs:subClassOf, solar:Satellite)
#     * (solar:Satellite, rdfs:subClassOf, solar:CelestialBody)
#
# * **(solar:Moon, rdf:type, solar:Satellite)**
# because:
#     * (solar:Moon, rdf:type, solar:NaturalSatellite)
#     * (solar:NaturalSatellite, rdfs:subClassOf, solar:Satellite)
#
# * **(solar:Sun, rdf:type, solar:CelestialBody)**
# because:
#     * (solar:Sun, rdf:type, solar:Star)
#     * (solar:Star, rdfs:subClassOf, solar:CelestialBody)
#
# * **(solar:Moon, rdf:type, solar:CelestialBody)**
# because:
#     * (solar:Moon, rdf:type, solar:NaturalSatelline)
#     * (solar:NaturalSatelline, rdfs:subClassOf, solar:CelestialBody)
#
# * **(solar:Earth, rdf:type, solar:CelestialBody)**
# because:
#     * (solar:Earth, rdf:type, solar:Planet)
#     * (solar:Planet, rdfs:subClassOf, solar:CelestialBody)
#
# * **(solar:Moon, solar:satelliteOf, solar:Earth)**
# because:
#     * (solar:naturalSatelliteOf, rdfs:subPropertyOf, solar:satelliteOf)
#     * (solar:Moon, solar:naturalSatelliteOf, solar:Earth)
#
# * **(solar:CelestialBody, rdfs:subClassOf, solar:CelestialBody)**
# because:
#     * (solar:CelestialBody, rdf:type, rdfs:Class)
#
# * **(X, rdfs:subPropertyOf, X)**
#     * **(solar:hasRadius, rdfs:subPropertyOf, solar:hasRadius)**
#     * **(solar:satelliteOf, rdfs:subPropertyOf, solar:satelliteOf)**
#     * **(rdfs:domain, rdfs:subPropertyOf, rdfs:domain)**
#     * **(rdf:type, rdfs:subPropertyOf, rdf:type)**
#     * **(rdfs:subPropertyOf, rdfs:subPropertyOf, rdfs:subPropertyOf)**
#     * **(rdfs:label, rdfs:subPropertyOf, rdfs:label)**
#     * **(rdfs:range, rdfs:subPropertyOf, rdfs:range)**
#     * **(solar:naturalSatelliteOf, rdfs:subPropertyOf, solar:naturalSatelliteOf)**
#     * **(rdfs:subClassOf, rdfs:subPropertyOf, rdfs:subClassOf)**
#
#         * because: (X, rdf:type, rdf:Property)

# %% [markdown]
# **RDF entailment** refers to the logical consequences or inferred statements that can be derived from a set of RDF triples based on specific semantic rules or reasoning.
#
# **Types of entailment:**
#
# * *Simple Entailment Rules*: RDFS includes rules for simple entailment, covering relationships such as subclass and subproperty relationships.
# * *RDF Entailment Rules*: These rules handle RDF entailment, encompassing assertions related to properties, types, and literals. They ensure completeness and provide a basis for entailment in RDF.
# * *RDFS Entailment Rules*: RDFS introduces additional entailment rules that go beyond simple RDF entailment. These include rules for handling subclass relationships, domain and range information, and other class-related inferences.
#     * *Extensional Entailment Rules (within RDFS)*: These rules ensure entailments based on the extensional semantics, involving additional patterns and relationships between classes and properties.
# * *Datatype Entailment Rules*: RDFS includes rules specific to datatype entailment. These rules deal with datatype-related information, including legal lexical forms, canonical forms, and relationships between datatypes.

# %% [markdown]
# ## Assignment part 2: your own webapplication.

# %% [markdown]
# **Exercise 4**
# 1. load ingredients.rdf and recipes.rdf in one graph. The graph contains types of individuals and types of relationships between them. Print all the classes and properties in the combined graph with the namespace `ind` and the `wtm` namespace/vocabulary (`http://purl.org/heals/food/`).
# 2. extend the `ind` vocabulary (`http://purl.org/heals/ingredient/`) by creating a hierarchy of ingredients (**hint: http://purl.org/heals/ingredient/CoconutMilk rdf:subClassOf http://purl.org/heals/ingredient/PlantMilk**), and make these superclasses human readable by giving them labels.
# 3. do the same for the `wtm` vocabulary: add a hierarchy of recipes as well as a hierarchy of properties (**hint: http://purl.org/heals/food/hasCookingTemperature rdf:subPropertyOf ...**)
# 4. print the entailed triples as we did in the previous exercise
# 5. give three examples of how RDF semantics could aid the chefs in your restaurant
# 6. which properties and classes could you add to the `wtm` and `ind` vocabularies to further describe your recipe and ingredient knowledge graph, aiding the chefs in your restaurant?

# %%
# In order to extend the vocabularies you have to come up with multiple examples that follows the given hierarchy

# %%
# 1. load ingredients.rdf and recipes.rdf in one graph
ingredients = Graph()
recipes = Graph()
g = Graph()
ingredients.parse("./data/ingredients.rdf")
recipes.parse("./data/recipes.rdf")
g.parse("./data/ingredients.rdf")
g.parse("./data/recipes.rdf")

print("Total # of statements:")
check_graph(g)
# Out:
# Total # of statements:
# The graph has 1299 statements.

# %%
IND = Namespace("http://purl.org/heals/ingredient/")
WTM = Namespace("http://purl.org/heals/food/")

# %%
# All classes
classes = set()
count = 0
for subj, pred, cl in g.triples((None, RDF.type, None)):
    if cl not in classes and (cl in IND or cl in WTM):
        print(f"class {cl}")
        classes.add(cl)
        count += 1
        properties = set()
        # All properties
        print(f"properties for the class:")
        for instance, p, o in g.triples((None, RDF.type, cl)):
            for s1, property, o1 in g.triples((instance, None, None)):
                if property not in properties:
                    print(property)
                    properties.add(property)
print(f"{count} classes")
# Out:
# class http://purl.org/heals/food/Ingredient
# properties for the class:
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://purl.org/heals/food/hasGluten
# http://purl.org/heals/food/hasGlycemicIndex
# http://purl.org/dc/terms/source
# http://www.w3.org/2000/01/rdf-schema#label
# http://www.w3.org/2004/02/skos/core#definition
# http://www.w3.org/2004/02/skos/core#scopeNote
# http://purl.org/heals/food/hasTexture
# http://purl.org/heals/food/substitutesFor
# http://www.w3.org/2004/02/skos/core#editorialNote
# class http://purl.org/heals/food/Yeast
# properties for the class:
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://purl.org/heals/food/hasGluten
# http://purl.org/heals/food/hasGlycemicIndex
# http://purl.org/dc/terms/source
# http://www.w3.org/2000/01/rdf-schema#label
# http://www.w3.org/2004/02/skos/core#definition
# http://www.w3.org/2004/02/skos/core#scopeNote
# class http://purl.org/heals/food/ChemicalFoodProduct
# properties for the class:
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://purl.org/heals/food/hasGluten
# http://purl.org/heals/food/hasGlycemicIndex
# http://purl.org/dc/terms/source
# http://www.w3.org/2000/01/rdf-schema#label
# http://www.w3.org/2004/02/skos/core#definition
# http://www.w3.org/2004/02/skos/core#scopeNote
# class http://purl.org/heals/food/MeatFromCow
# properties for the class:
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://purl.org/heals/food/hasGluten
# http://purl.org/heals/food/hasGlycemicIndex
# http://purl.org/dc/terms/source
# http://www.w3.org/2000/01/rdf-schema#label
# http://www.w3.org/2004/02/skos/core#definition
# http://www.w3.org/2004/02/skos/core#scopeNote
# class http://purl.org/heals/food/Flavor
# properties for the class:
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://purl.org/dc/terms/source
# http://www.w3.org/2000/01/rdf-schema#label
# http://www.w3.org/2004/02/skos/core#definition
# http://www.w3.org/2004/02/skos/core#scopeNote
# http://www.w3.org/2004/02/skos/core#editorialNote
# class http://purl.org/heals/food/TemperatureMeasurement
# properties for the class:
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://purl.org/dc/terms/source
# http://www.w3.org/2000/01/rdf-schema#label
# http://www.w3.org/2004/02/skos/core#definition
# http://www.w3.org/2004/02/skos/core#editorialNote
# http://www.w3.org/2004/02/skos/core#scopeNote
# class http://purl.org/heals/food/MeatFromChicken
# properties for the class:
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://purl.org/heals/food/hasGluten
# http://purl.org/heals/food/hasGlycemicIndex
# http://purl.org/dc/terms/source
# http://www.w3.org/2000/01/rdf-schema#label
# http://www.w3.org/2004/02/skos/core#definition
# http://www.w3.org/2004/02/skos/core#scopeNote
# class http://purl.org/heals/food/MilkFromCow
# properties for the class:
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://purl.org/heals/food/hasGluten
# http://purl.org/heals/food/hasGlycemicIndex
# http://purl.org/dc/terms/source
# http://www.w3.org/2000/01/rdf-schema#label
# http://www.w3.org/2004/02/skos/core#definition
# http://www.w3.org/2004/02/skos/core#scopeNote
# class http://purl.org/heals/food/Texture
# properties for the class:
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://purl.org/dc/terms/source
# http://www.w3.org/2000/01/rdf-schema#label
# http://www.w3.org/2004/02/skos/core#definition
# http://www.w3.org/2004/02/skos/core#scopeNote
# http://www.w3.org/2004/02/skos/core#editorialNote
# class http://purl.org/heals/food/TimeMeasurement
# properties for the class:
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://purl.org/dc/terms/source
# http://www.w3.org/2000/01/rdf-schema#label
# http://www.w3.org/2004/02/skos/core#altLabel
# http://www.w3.org/2004/02/skos/core#definition
# http://www.w3.org/2004/02/skos/core#scopeNote
# class http://purl.org/heals/food/MeatFromLamb
# properties for the class:
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://purl.org/heals/food/hasGluten
# http://purl.org/heals/food/hasGlycemicIndex
# http://purl.org/dc/terms/source
# http://www.w3.org/2000/01/rdf-schema#label
# http://www.w3.org/2004/02/skos/core#definition
# http://www.w3.org/2004/02/skos/core#scopeNote
# class http://purl.org/heals/food/User
# properties for the class:
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://purl.org/heals/food/dislikes
# http://purl.org/heals/food/forbids
# http://purl.org/heals/food/isAllergicTo
# http://purl.org/dc/terms/source
# http://www.w3.org/2000/01/rdf-schema#label
# http://www.w3.org/2004/02/skos/core#definition
# http://www.w3.org/2004/02/skos/core#scopeNote
# class http://purl.org/heals/food/Recipe
# properties for the class:
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://purl.org/heals/food/hasIngredient
# http://purl.org/heals/food/isRecommendedForCourse
# http://purl.org/heals/food/isRecommendedForMeal
# http://purl.org/heals/food/hasCookTime
# http://purl.org/heals/food/hasCookingTemperature
# http://purl.org/heals/food/serves
# http://purl.org/dc/terms/source
# http://www.w3.org/2000/01/rdf-schema#label
# http://www.w3.org/2004/02/skos/core#definition
# http://www.w3.org/2004/02/skos/core#scopeNote
# http://www.w3.org/ns/prov#wasDerivedFrom
# http://www.w3.org/2004/02/skos/core#editorialNote
# 13 classes

# %%
# 2. extend the IND vocabulary by creating a hierarchy of ingredients
# and make these superclasses human readable by giving them labels
g.add((IND.PlantMilk, RDFS.subClassOf, ind.ingredient))
g.add((IND.PlantMilk, RDFS.label, Literal('PlantMilk')))
g.add((IND.CoconutMilk, RDFS.subClassOf, IND.PlantMilk))

g.add((IND.Meat, RDFS.subClassOf, ind.ingredient))
g.add((IND.Meat, RDFS.label, Literal('Meat')))
g.add((IND.Bacon, RDFS.subClassOf, IND.Meat))
g.add((IND.Beef, RDFS.subClassOf, IND.Meat))
g.add((IND.Chicken, RDFS.subClassOf, IND.Meat))
g.add((IND.ChuckRoast, RDFS.subClassOf, IND.Meat))
g.add((IND.Lamb, RDFS.subClassOf, IND.Meat))
g.add((IND.CornedBeef, RDFS.subClassOf, IND.Meat))
g.add((IND.GrilledChickenKabob, RDFS.subClassOf, IND.Meat))
g.add((IND.SmotheredChickenBreast, RDFS.subClassOf, IND.Meat))

g.add((IND.Sweeteners, RDFS.subClassOf, ind.ingredient))
g.add((IND.Sweeteners, RDFS.label, Literal('Sweeteners')))
g.add((IND.Brownies, RDFS.subClassOf, IND.Sweeteners))
g.add((IND.Honey, RDFS.subClassOf, IND.Sweeteners))
g.add((IND.WhiteBread, RDFS.subClassOf, IND.Sweeteners))

g.add((IND.NutsAndSeeds, RDFS.subClassOf, ind.ingredient))
g.add((IND.NutsAndSeeds, RDFS.label, Literal('NutsAndSeeds')))
g.add((IND.Walnut, RDFS.subClassOf, IND.NutsAndSeeds))
g.add((IND.AlmondBiscotti, RDFS.subClassOf, IND.NutsAndSeeds))
g.add((IND.DriedCranberry, RDFS.subClassOf, IND.NutsAndSeeds))
g.add((IND.Pecan, RDFS.subClassOf, IND.NutsAndSeeds))

g.add((IND.Liquids, RDFS.subClassOf, ind.ingredient))
g.add((IND.Liquids, RDFS.label, Literal('Liquids')))
g.add((IND.Water, RDFS.subClassOf, IND.Liquids))
g.add((IND.CoconutMilk, RDFS.subClassOf, IND.Liquids))
g.add((IND.AppleCiderVinegar, RDFS.subClassOf, IND.Liquids))
g.add((IND.OliveOil, RDFS.subClassOf, IND.Liquids))
g.add((IND.SesameOil, RDFS.subClassOf, IND.Liquids))
g.add((IND.BalsamicVinegar, RDFS.subClassOf, IND.Liquids))
g.add((IND.WhiteVinegar, RDFS.subClassOf, IND.Liquids))
# Out:
# <Graph identifier=N1b8c425144e3497cb7c47a0e84226c9d (<class 'rdflib.graph.Graph'>)>

# %%
# ss = set()
# count = 0
# for s, p, o in g.triples((None, None, None)):
#     uri = o
#     if uri not in ss and uri in WTM:
#         print(uri)
#         ss.add(uri)
#         count += 1
# #print(count)

# for s, p, o in g.triples((None, None, None)):
#     uri = p
#     if uri not in ss and uri in WTM:
#         print(uri)
#         ss.add(uri)
#         count += 1

# %%
for s, p, o in g.triples((None, WTM.isRecommendedForCourse, None)):
    print(o)
# Out:
# http://purl.org/heals/food/Dessert
# http://purl.org/heals/food/Dessert
# http://purl.org/heals/food/Dessert
# http://purl.org/heals/food/Dessert
# http://purl.org/heals/food/Dessert
# http://purl.org/heals/food/Dessert
# http://purl.org/heals/food/Entree
# http://purl.org/heals/food/Entree
# http://purl.org/heals/food/Entree
# http://purl.org/heals/food/Entree
# http://purl.org/heals/food/Entree
# http://purl.org/heals/food/Entree
# http://purl.org/heals/food/Entree
# http://purl.org/heals/food/Entree
# http://purl.org/heals/food/Entree
# http://purl.org/heals/food/Entree
# http://purl.org/heals/food/Side
# http://purl.org/heals/food/Side
# http://purl.org/heals/food/Side
# http://purl.org/heals/food/Snack
# http://purl.org/heals/food/Appetizer
# http://purl.org/heals/food/Appetizer
# http://purl.org/heals/food/Appetizer
# http://purl.org/heals/food/Appetizer

# %%
# 3. extend the WTM vocabulary
g.add((wtm.Meals, RDF.type, RDFS.Class))
g.add((wtm.Breakfast, RDFS.subClassOf, wtm.Meals))
g.add((wtm.Lunch, RDFS.subClassOf, wtm.Meals))
g.add((wtm.Dinner, RDFS.subClassOf, wtm.Meals))

g.add((wtm.Courses, RDF.type, RDFS.Class))
g.add((wtm.Snack, RDFS.subClassOf, wtm.Courses))
g.add((wtm.Entree, RDFS.subClassOf, wtm.Courses))
g.add((wtm.Appetizer, RDFS.subClassOf, wtm.Courses))
g.add((wtm.Side, RDFS.subClassOf, wtm.Courses))
g.add((wtm.Dessert, RDFS.subClassOf, wtm.Courses))

g.add((wtm.hasGluten, RDFS.subPropertyOf, wtm.hasIngredient))

g.add((wtm.procedure, RDF.type, RDF.Property))
g.add((wtm.hasCookingTemperature, RDFS.subPropertyOf, wtm.procedure))
g.add((wtm.hasCookTime, RDFS.subPropertyOf, wtm.procedure))
# Out:
# <Graph identifier=N1b8c425144e3497cb7c47a0e84226c9d (<class 'rdflib.graph.Graph'>)>

# %%
# 4. print the entailed triples
expanded = Graph()
expanded.parse("data/ingredients.rdf")
expanded.parse("data/recipes.rdf")
DeductiveClosure(RDFS_Semantics).expand(expanded)

derived = Graph()
derived = expanded - g
derived.namespace_manager.bind('ind', IND)
derived.namespace_manager.bind('wtm', WTM)

print("Total # of statements:")
check_graph(derived)
print("\n")

for subj, pred, obj in derived:
    print(f"({subj.n3(derived.namespace_manager)}, {pred.n3(derived.namespace_manager)}, {obj.n3(derived.namespace_manager)})")
# Out:
# Total # of statements:
# The graph has 844 statements.
#
#
# (ind:Peanut, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# (ind:GreenPepper, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# ("gluten free flour", rdf:type, rdfs:Resource)
# (ind:SaucyShepherdPie, wtm:hasCookTime, "50"^^xsd:nonNegativeInteger)
# (ind:VanillaExtract, rdf:type, rdfs:Resource)
# ("Dictionary.com, \"cilantro.\" [Online]. Available: https://www.dictionary.com/browse/cilantro. [Accessed Nov. 10, 2018]", rdf:type, rdfs:Resource)
# (dcterms:source, rdf:type, rdf:Property)
# (wtm:Side, rdf:type, rdfs:Resource)
# ("walnut", rdf:type, rdfs:Resource)
# ("black peppercorn", rdf:type, rdfs:Resource)
# ("celsius", rdf:type, rdfs:Resource)
# ("kamut muffin", rdf:type, rdfs:Resource)
# (ind:Cilantro, rdf:type, rdfs:Resource)
# ("a cake frosted with a white frosting and covered in coconut flakes, with no ingredients contain gluten", rdf:type, rdfs:Resource)
# (ind:Cornstarch, wtm:hasGlycemicIndex, "0"^^xsd:nonNegativeInteger)
# (ind:Spicy, rdf:type, rdfs:Resource)
# ("Dictionary.com, \"bacon.\" [Online]. Available: https://www.dictionary.com/browse/bacon. [Accessed Nov. 10, 2018]", rdf:type, rdfs:Resource)
# ("Wikipedia, \"Milk.\" [Online]. Available: https://en.wikipedia.org/wiki/Milk#Cow's_milk. [Accessed: Nov. 10, 2018]", rdf:type, rdfs:Resource)
# ("Dictionary.com, \"vinegar.\" [Online]. Available: https://www.dictionary.com/browse/vinegar. [Accessed Nov. 10, 2018]", rdf:type, rdfs:Resource)
# ("crumbly", rdf:type, rdfs:Resource)
# (ind:BakingSoda, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# ("gluten free coconut cake", rdf:type, rdfs:Resource)
# ("The Spruce Eats, \"What Is Cocoa Powder?,\"  2018.  [Online]. Available: https://www.thespruceeats.com/what-is-cocoa-powder-520351. [Accessed: 1-Nov-2018]", rdf:type, rdfs:Resource)
# ("https://www.kingarthurflour.com/recipes/simply-perfect-pancakes-recipe", rdf:type, rdfs:Resource)
# ("\"Balsamic vinegar,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/balsamic%20vinegar. [Accessed: 1-Nov-2018]", rdf:type, rdfs:Resource)
# ("nutty", rdf:type, rdfs:Resource)
# (wtm:hasGluten, rdfs:subPropertyOf, wtm:hasGluten)
# (wtm:hasTexture, rdf:type, rdf:Property)
# (ind:Crumbly, rdf:type, rdfs:Resource)
# (<http://purl.obolibrary.org/obo/FOODON_03400662>, rdf:type, rdfs:Resource)
# ("https://www.kingarthurflour.com/recipes/basic-muffins-with-berry-and-oatmeal-versions-recipe", rdf:type, rdfs:Resource)
# (ind:Peanut, wtm:hasGlycemicIndex, "15"^^xsd:integer)
# (ind:CornedBeef, wtm:hasGlycemicIndex, "false"^^xsd:boolean)
# ("easily crumbled", rdf:type, rdfs:Resource)
# (wtm:hasGlycemicIndex, rdfs:subPropertyOf, wtm:hasGlycemicIndex)
# (ind:ChickenEgg, wtm:hasGlycemicIndex, "false"^^xsd:boolean)
# (ind:OliveOil, wtm:hasGlycemicIndex, "false"^^xsd:boolean)
# ("pecan", rdf:type, rdfs:Resource)
# ("\"Crumbly,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/crumbly. [Accessed: 18-Oct-2018].", rdf:type, rdfs:Resource)
# ("almond meal", rdf:type, rdfs:Resource)
# (ind:BalsamicVinegar, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# ("15"^^xsd:nonNegativeInteger, rdf:type, rdfs:Resource)
# ("parsley", rdf:type, rdfs:Resource)
# ("\"Moist,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/moist. [Accessed: 18-Oct-2018].", rdf:type, rdfs:Resource)
# (wtm:TimeMeasurement, rdf:type, rdfs:Resource)
# ("a solution made by macerating and percolating vanilla pods in a solution of ethanol and water", rdf:type, rdfs:Resource)
# (<http://purl.obolibrary.org/obo/FOODON_03400678>, rdf:type, rdfs:Resource)
# (wtm:isRecommendedForMeal, rdfs:subPropertyOf, wtm:isRecommendedForMeal)
# ("a Filipino beef soup cooked until the meat becomes really tender and with vegetables like potatoes, beans, and cabbage that makes this simple soup healthy and flavorful", rdf:type, rdfs:Resource)
# ("\"chayote,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/chayote. [Accessed: 1-Nov-2018].", rdf:type, rdfs:Resource)
# (ind:AppleCiderVinegar, wtm:hasGlycemicIndex, "5"^^xsd:integer)
# (ind:Mayonnaise, wtm:hasGluten, "1"^^xsd:integer)
# ("\"Olive oil,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/olive%20oil. [Accessed: 1-Nov-2018]", rdf:type, rdfs:Resource)
# (ind:Pecan, rdf:type, rdfs:Resource)
# ("Wikipedia, \"Banana bread,\" Oct. 2018. [Online]. Available: https://en.wikipedia.org/wiki/Banana_bread. [Accessed Oct. 13, 2018]", rdf:type, rdfs:Resource)
# ("coconut milk", rdf:type, rdfs:Resource)
# (ind:Banana, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# ("the meat of sheep", rdf:type, rdfs:Resource)
# ("a salty, fermented sauce prepared from soybeans, used in East Asian cuisine", rdf:type, rdfs:Resource)
# (ind:BlackPeppercorn, wtm:hasGlycemicIndex, "5"^^xsd:integer)
# ("https://www.allrecipes.com/recipe/222607/smothered-chicken-breasts/?internalSource=hub%20recipe&referringContentType=Search", rdf:type, rdfs:Resource)
# (<http://purl.obolibrary.org/obo/FOODON_03400667>, rdf:type, rdfs:Resource)
# ("green onion", rdf:type, rdfs:Resource)
# ("of, seasoned with, or containing salt", rdf:type, rdfs:Resource)
# (ind:Kamut, wtm:hasGluten, "1"^^xsd:integer)
# ("gooey", rdf:type, rdfs:Resource)
# (ind:Cabbage, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# ("\"Creamy,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/creamy. [Accessed: 18-Oct-2018].", rdf:type, rdfs:Resource)
# ("beef stew", rdf:type, rdfs:Resource)
# (ind:Beef, wtm:hasGlycemicIndex, "false"^^xsd:boolean)
# ("55"^^xsd:nonNegativeInteger, rdf:type, rdfs:Resource)
# ("https://www.allrecipes.com/recipe/260575/chef-johns-almond-biscotti/?internalSource=hub%20recipe&referringContentType=Search.", rdf:type, rdfs:Resource)
# (ind:FlourlessCoconutAndAlmondCake, wtm:hasCookTime, "60"^^xsd:nonNegativeInteger)
# (wtm:dislikes, rdfs:subPropertyOf, wtm:dislikes)
# (wtm:Snack, rdf:type, rdfs:Resource)
# ("35"^^xsd:nonNegativeInteger, rdf:type, rdfs:Resource)
# ("\"Walnut,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/walnut. [Accessed: 12-Oct-2018].", rdf:type, rdfs:Resource)
# ("https://diabetesstrong.com/mustard-baked-chicken-tenders/", rdf:type, rdfs:Resource)
# (ind:BananaBlueberryAlmondFlourMuffin, wtm:hasCookTime, "60"^^xsd:nonNegativeInteger)
# (rdfs:subPropertyOf, rdfs:subPropertyOf, rdfs:subPropertyOf)
# (ind:CoconutMilk, wtm:hasGlycemicIndex, "40"^^xsd:integer)
# ("chayote squash", rdf:type, rdfs:Resource)
# ("\"Sweet,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/sweet. [Accessed: 18-Oct-2018].", rdf:type, rdfs:Resource)
# ("\"Cornstarch ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/cornstarch. [Accessed: 26-Oct-2018].", rdf:type, rdfs:Resource)
# (wtm:ChemicalFoodProduct, rdf:type, rdfs:Resource)
# ("water", rdf:type, rdfs:Resource)
# (ind:Tarragon, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# (ind:Crunchy, rdf:type, rdfs:Resource)
# (ind:CoconutMilk, rdf:type, rdfs:Resource)
# ("bacon", rdf:type, rdfs:Resource)
# ("salt", rdf:type, rdfs:Resource)
# (<http://purl.obolibrary.org/obo/FOODON_03400776>, rdf:type, rdfs:Resource)
# (ind:BakersYeast, wtm:hasGlycemicIndex, "35"^^xsd:integer)
# ("oregano", rdf:type, rdfs:Resource)
# (ind:Carrot, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# (wtm:MeatFromCow, rdf:type, rdfs:Resource)
# ("the common domestic fowl", rdf:type, rdfs:Resource)
# ("potato", rdf:type, rdfs:Resource)
# (ind:Cabbage, wtm:hasGlycemicIndex, "15"^^xsd:integer)
# ("\"Spicy,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/spicy. [Accessed: 18-Oct-2018].", rdf:type, rdfs:Resource)
# (ind:KamutFlour, wtm:hasGlycemicIndex, "45"^^xsd:integer)
# ("foodrepublic.com, \"What Is Kamut?\" [Online]. Available: http://www.foodrepublic.com/2013/04/15/what-is-kamut/. [Accessed Nov.9, 2018]", rdf:type, rdfs:Resource)
# (dcterms:abstract, rdfs:subPropertyOf, dcterms:abstract)
# ("sugar obtained from sugar cane, identical with that obtained from the sugar beet", rdf:type, rdfs:Resource)
# ("60"^^xsd:nonNegativeInteger, rdf:type, rdfs:Resource)
# (dcterms:contributor, rdfs:subPropertyOf, dcterms:contributor)
# ("\"Thyme,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/thyme. [Accessed: 1-Nov-2018]", rdf:type, rdfs:Resource)
# ("a food dish that combines beef with a variety of other ingredients, such as potatoes, vegetables, herbs, spices, and broth to create a savory dish, rich in flavor and often served as the main dish", rdf:type, rdfs:Resource)
# (ind:Almond, rdf:type, rdfs:Resource)
# (ind:AlmondMeal, rdf:type, rdfs:Resource)
# ("https://www.allrecipes.com/recipe/33129/corned-beef-hash/?internalSource=hub%20recipe&referringContentType=Search", rdf:type, rdfs:Resource)
# (dcterms:abstract, rdf:type, rdf:Property)
# ("an unsweetened powder produced by grinding the seeds of the fruit of a tropical evergreen tree called the cacao, or cocoa tree", rdf:type, rdfs:Resource)
# ("60"^^xsd:integer, rdf:type, rdfs:Resource)
# ("milk obtained from a cow", rdf:type, rdfs:Resource)
# (ind:AllPurposeFlour, rdf:type, rdfs:Resource)
# (ind:Smoky, rdf:type, rdfs:Resource)
# ("Forest Eckhardt", rdf:type, rdfs:Resource)
# ("rosemary", rdf:type, rdfs:Resource)
# (ind:ChickenBroth, rdf:type, rdfs:Resource)
# ("10"^^xsd:integer, rdf:type, rdfs:Resource)
# ("This is a subclass of texture and is one of the textural components that could be considered for substitutions", rdf:type, rdfs:Resource)
# ("Dictionary.com, \"hour.\" [Online]. Available: https://www.dictionary.com/browse/hour. [Accessed Oct. 5, 2018]", rdf:type, rdfs:Resource)
# ("banana bread", rdf:type, rdfs:Resource)
# (dcterms:publisher, rdfs:subPropertyOf, dcterms:publisher)
# (ind:Water, wtm:hasGlycemicIndex, "false"^^xsd:boolean)
# (ind:GreenPepper, wtm:hasGlycemicIndex, "15"^^xsd:integer)
# (wtm:User, rdf:type, rdfs:Resource)
# (ind:Creamy, rdf:type, rdfs:Resource)
# ("Wikipedia, \"Hash (food),\" Aug. 2018. [Online]. Available: https://en.wikipedia.org/wiki/Hash_(food). [Accessed Oct. 18, 2018]", rdf:type, rdfs:Resource)
# (wtm:Yeast, rdf:type, rdfs:Resource)
# (<http://www.omg.org/techprocess/ab/SpecificationMetadata/>, rdf:type, rdfs:Resource)
# ("used as a flavor", rdf:type, rdfs:Resource)
# ("used as an ingredient", rdf:type, rdfs:Resource)
# (ind:BlackPepper, wtm:hasGlycemicIndex, "5"^^xsd:integer)
# (ind:Bacon, wtm:hasGlycemicIndex, "false"^^xsd:boolean)
# (ind:Garlic, wtm:hasGlycemicIndex, "30"^^xsd:integer)
# ("A potential substitution for members of the tree nut family", rdf:type, rdfs:Resource)
# ("a cereal grass, Avena sativa, cultivated for its edible seed", rdf:type, rdfs:Resource)
# ("Member of the tree nut family which is a common allergen", rdf:type, rdfs:Resource)
# (ind:SmotheredChickenBreast, rdf:type, rdfs:Resource)
# (ind:PotRoastWithVegetables, rdf:type, rdfs:Resource)
# ("used as a texture", rdf:type, rdfs:Resource)
# (ind:CornedBeefHash, wtm:hasCookTime, "40"^^xsd:nonNegativeInteger)
# ("value of temperature", rdf:type, rdfs:Resource)
# ("olive oil", rdf:type, rdfs:Resource)
# (ind:Beef, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# (ind:Parsley, rdf:type, rdfs:Resource)
# ("smothered chicken breast", rdf:type, rdfs:Resource)
# (ind:ChickenSalad, wtm:hasCookTime, "15"^^xsd:nonNegativeInteger)
# (wtm:Appetizer, rdf:type, rdfs:Resource)
# ("a yellow oil expressed from the seeds of the sesame, used in cooking, as a vehicle for medicines, and in the manufacture of margarine, soap, and cosmetics", rdf:type, rdfs:Resource)
# ("almond", rdf:type, rdfs:Resource)
# (ind:CornedBeef, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# ("\"Carrot,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/carrot. [Accessed: 13-Oct-2018].", rdf:type, rdfs:Resource)
# ("\"Tomato,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/tomato. [Accessed: 1-Nov-2018]", rdf:type, rdfs:Resource)
# (<http://purl.obolibrary.org/obo/FOODON_03400685>, rdf:type, rdfs:Resource)
# ("20"^^xsd:nonNegativeInteger, rdf:type, rdfs:Resource)
# ("being or inducing the one of the four basic taste sensations that is typically induced by disaccharides and is mediated especially by receptors in taste buds at the front of the tongue", rdf:type, rdfs:Resource)
# (ind:ChickenEgg, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# ("true"^^xsd:boolean, rdf:type, rdfs:Resource)
# ("12"^^xsd:integer, rdf:type, rdfs:Resource)
# ("5"^^xsd:nonNegativeInteger, rdf:type, rdfs:Resource)
# ("\"Clove,\" WIKIPEDIA [Online]. Available: https://en.wikipedia.org/wiki/Clove [Accessed: 26-Oct-2018].", rdf:type, rdfs:Resource)
# (ind:VegetableOil, rdf:type, rdfs:Resource)
# (<http://purl.obolibrary.org/obo/FOODON_03400683>, rdf:type, rdfs:Resource)
# ("a flour made from the tapioca plant", rdf:type, rdfs:Resource)
# (ind:BraisedBalsamicChicken, wtm:hasCookTime, "35"^^xsd:nonNegativeInteger)
# (ind:WholeGrainMustard, rdf:type, rdfs:Resource)
# ("Dictionary.com, \"green onion.\" [Online]. Available: https://www.dictionary.com/browse/green-onion. [Accessed Nov. 10, 2018]", rdf:type, rdfs:Resource)
# ("chicken", rdf:type, rdfs:Resource)
# ("a bushy perennial mint (Origanum vulgare) with leaves that are used as a seasoning and a source of aromatic oil", rdf:type, rdfs:Resource)
# ("flour that is ground from the whole grain and contains all the constituents of the wheat kernels", rdf:type, rdfs:Resource)
# ("a widely cultivated Asian herb of the lily family with pungent edible bulbs", rdf:type, rdfs:Resource)
# ("50"^^xsd:integer, rdf:type, rdfs:Resource)
# (ind:Carrot, wtm:hasGlycemicIndex, "15"^^xsd:integer)
# ("Allrecipes.com, \"Fruited Curry Chicken Salad,\" 2010. [Online]. Available: https://www.allrecipes.com/recipe/15735/fruited-curry-chicken-salad/?internalSource=hub%20recipe&referringContentType=Search. [Accessed Nov.9, 2018]", rdf:type, rdfs:Resource)
# ("Dictionary.com, \"almond.\" [Online]. Available: https://www.dictionary.com/browse/almond. [Accessed Oct. 20, 2018]", rdf:type, rdfs:Resource)
# ("Dictionary.com, \"coconut.\" [Online]. Available: https://www.dictionary.com/browse/coconut. [Accessed Nov. 10, 2018]", rdf:type, rdfs:Resource)
# (ind:Tarragon, rdf:type, rdfs:Resource)
# (wtm:hasTexture, rdfs:subPropertyOf, wtm:hasTexture)
# ("\"Parsley ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/parsley. [Accessed: 26-Oct-2018].", rdf:type, rdfs:Resource)
# ("The goal of this project is to create a system capable of recommending recipes to a user subject to the ingredients that user has on hand and the time they want to spend cooking. The system should also be able to recommend best-matched substitutions for ingredients where appropriate in order to meet the user’s taste preferences or food allergy related needs. The users are allowed to specify the meal types (e.g. lunch) and course types (e.g. entree) in the request. If the users request not to have recipes that contain high Glycemic Index (GI) ingredients, the system will avoid offering these high glycemic recipes in the recommendations.", rdf:type, rdfs:Resource)
# ("\"Rosemary ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/rosemary. [Accessed: 26-Oct-2018].", rdf:type, rdfs:Resource)
# ("grilled chicken kabob", rdf:type, rdfs:Resource)
# (dcterms:references, rdfs:subPropertyOf, dcterms:references)
# (ind:BrownSugar, rdf:type, rdfs:Resource)
# (prov:wasDerivedFrom, rdfs:subPropertyOf, prov:wasDerivedFrom)
# (ind:Clove, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# ("widely cultivated for its pungent compound bulbs much used in cookery", rdf:type, rdfs:Resource)
# (ind:LemonJuice, rdf:type, rdfs:Resource)
# (skos:changeNote, rdf:type, rdf:Property)
# ("a European herb the carrot family specifically one of a cultivated variety with leafstalks eaten raw or cooked", rdf:type, rdfs:Resource)
# (ind:BlackPepper, rdf:type, rdfs:Resource)
# ("khorasan wheat (kamut) is an ancient grain", rdf:type, rdfs:Resource)
# (ind:GlutenFreeFlour, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# ("the sixtieth part (1/60) of an hour; sixty seconds", rdf:type, rdfs:Resource)
# (ind:ChuckRoast, rdf:type, rdfs:Resource)
# (<http://purl.obolibrary.org/obo/FOODON_03400760>, rdf:type, rdfs:Resource)
# (dcterms:license, rdf:type, rdf:Property)
# (ind:SesameOil, rdf:type, rdfs:Resource)
# ("https://tw.rpi.edu/Courses/Ontologies/2018/WhatToMake/WhatToMake_Individuals/", rdf:type, rdfs:Resource)
# ("soy sauce", rdf:type, rdfs:Resource)
# ("the edible, usually bluish berry of various shrubs belonging to the genus Vaccinium, of the heath family", rdf:type, rdfs:Resource)
# ("an ingredient made from ground up almonds", rdf:type, rdfs:Resource)
# (rdfs:subPropertyOf, rdf:type, rdf:Property)
# ("\"Chuck steak,\" WIKIPEDIA [Online]. Available: https://en.wikipedia.org/wiki/Chuck_steak [Accessed: 26-Oct-2018].", rdf:type, rdfs:Resource)
# (rdfs:label, rdf:type, rdf:Property)
# ("chicken salad", rdf:type, rdfs:Resource)
# (ind:Bacon, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# (ind:Coconut, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# (wtm:Entree, rdf:type, rdfs:Resource)
# ("all purpose flour", rdf:type, rdfs:Resource)
# (ind:Water, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# (ind:BakingSoda, rdf:type, rdfs:Resource)
# ("Allrecipes.com, \"Rosemary Ranch Chicken Kabobs,\" 2010. [Online]. Available: https://www.allrecipes.com/recipe/64513/rosemary-ranch-chicken-kabobs/?internalSource=hub%20recipe&referringContentType=Search. [Accessed Nov.9, 2018]", rdf:type, rdfs:Resource)
# (ind:Cabbage, rdf:type, rdfs:Resource)
# ("Dictionary.com, \"oat.\" [Online]. Available: https://www.dictionary.com/browse/oat. [Accessed Nov. 10, 2018]", rdf:type, rdfs:Resource)
# (ind:ThaiChicken, rdf:type, rdfs:Resource)
# ("https://www.recipetips.com/glossary-term/t--36245/beef-stew.asp", rdf:type, rdfs:Resource)
# (ind:BakingPowder, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# (<http://purl.obolibrary.org/obo/FOODON_03400759>, rdf:type, rdfs:Resource)
# ("lemon juice", rdf:type, rdfs:Resource)
# ("65"^^xsd:integer, rdf:type, rdfs:Resource)
# (ind:DriedCranberry, rdf:type, rdfs:Resource)
# ("Allrecipes.com, \"Chef John's Almond Biscotti,\" 2010. [Online]. Available: https://www.allrecipes.com/recipe/260575/chef-johns-almond-biscotti/?internalSource=hub%20recipe&referringContentType=Search. [Accessed Nov.9, 2018]", rdf:type, rdfs:Resource)
# (ind:WhiteSugar, rdf:type, rdfs:Resource)
# ("\"Greasy,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/greasy. [Accessed: 18-Oct-2018].", rdf:type, rdfs:Resource)
# (<https://www.omg.org/techprocess/ab/SpecificationMetadata/copyright>, rdf:type, rdf:Property)
# ("Recipetips.com, \"Beef Stew,\" 2018. [Online]. Available: https://www.recipetips.com/glossary-term/t--36245/beef-stew.asp. [Accessed Oct. 13, 2018]", rdf:type, rdfs:Resource)
# (ind:CowMilk, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# ("https://www.myrecipes.com/quick-and-easy/how-to-cook-pot-roast", rdf:type, rdfs:Resource)
# ("\"Vegetable Oil ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/vegetable oil. [Accessed: 26-Oct-2018].", rdf:type, rdfs:Resource)
# (ind:SoySauce, wtm:hasGlycemicIndex, "false"^^xsd:boolean)
# ("the strains of yeast commonly used as a leavening agent in baking bread and bakery products, where it converts the fermentable sugars present in the dough into carbon dioxide and ethanol", rdf:type, rdfs:Resource)
# (ind:Honey, wtm:hasGlycemicIndex, "60"^^xsd:integer)
# ("golden kamut bread", rdf:type, rdfs:Resource)
# (wtm:isRecommendedForCourse, rdfs:subPropertyOf, wtm:isRecommendedForCourse)
# (ind:Lamb, wtm:hasGlycemicIndex, "false"^^xsd:boolean)
# ("saucy shepherd pie", rdf:type, rdfs:Resource)
# ("cow milk", rdf:type, rdfs:Resource)
# ("the curd of milk separated from the whey and prepared in many ways as a food", rdf:type, rdfs:Resource)
# (dcterms:modified, rdfs:subPropertyOf, dcterms:modified)
# ("chicken egg", rdf:type, rdfs:Resource)
# ("Yarden Ne'eman", rdf:type, rdfs:Resource)
# ("any of a genus (Thymus) of Eurasian mints with small pungent aromatic leaves", rdf:type, rdfs:Resource)
# ("\"Flour,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/flour. [Accessed: 13-Oct-2018].", rdf:type, rdfs:Resource)
# (ind:Paprika, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# (wtm:MeatFromLamb, rdf:type, rdfs:Resource)
# (ind:Mayonnaise, rdf:type, rdfs:Resource)
# ("carrot", rdf:type, rdfs:Resource)
# ("180"^^xsd:integer, rdf:type, rdfs:Resource)
# (ind:Onion, rdf:type, rdfs:Resource)
# ("Techopedia, \"User Identification (User ID),\" 2018. [Online]. Available: https://www.techopedia.com/definition/12552/user-identification-user-id. [Accessed Oct. 18, 2018]", rdf:type, rdfs:Resource)
# ("containing an unusual amount of grease", rdf:type, rdfs:Resource)
# ("Dictionary.com, \"cheese.\" [Online]. Available: https://www.dictionary.com/browse/cheese. [Accessed Nov. 10, 2018]", rdf:type, rdfs:Resource)
# (ind:ChayoteSquash, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# ("represents an individual user", rdf:type, rdfs:Resource)
# (ind:User15, rdf:type, rdfs:Resource)
# (ind:Honey, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# ("beef nilaga", rdf:type, rdfs:Resource)
# ("Dictionary.com, \"minute.\" [Online]. Available: https://www.dictionary.com/browse/minute?s=t. [Accessed Oct. 5, 2018]", rdf:type, rdfs:Resource)
# ("95"^^xsd:nonNegativeInteger, rdf:type, rdfs:Resource)
# (ind:Celery, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# ("a kabob dish made from chicken", rdf:type, rdfs:Resource)
# ("the nutlike kernel of the fruit of either of two trees, Prunus dulcis (sweet almond) or P. dulcis amara (bitter almond), which grow in warm temperate regions", rdf:type, rdfs:Resource)
# (wtm:Dinner, rdf:type, rdfs:Resource)
# ("\"Mushy,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/mushy. [Accessed: 18-Oct-2018].", rdf:type, rdfs:Resource)
# ("apple cider vinegar", rdf:type, rdfs:Resource)
# (ind:GreenOnion, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# (owl:Ontology, rdf:type, rdfs:Resource)
# ("\"Garlic ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/garlic. [Accessed: 26-Oct-2018].", rdf:type, rdfs:Resource)
# ("50"^^xsd:nonNegativeInteger, rdf:type, rdfs:Resource)
# ("the clear, potable liquid contained within the young hollow seed of the coconut palm", rdf:type, rdfs:Resource)
# (ind:Paprika, wtm:hasGlycemicIndex, "15"^^xsd:integer)
# ("25"^^xsd:nonNegativeInteger, rdf:type, rdfs:Resource)
# ("Dictionary.com, \"soy sauce.\" [Online]. Available: https://www.dictionary.com/browse/soy-sauce. [Accessed Nov. 10, 2018]", rdf:type, rdfs:Resource)
# (ind:GlutenFreeCoconutCake, rdf:type, rdfs:Resource)
# ("a young onion with a slender green stalk and a small bulb, used as a table vegetable, usually raw,especially in salads; scallion", rdf:type, rdfs:Resource)
# ("hours", rdf:type, rdfs:Resource)
# (<http://purl.obolibrary.org/obo/FOODON_03400677>, rdf:type, rdfs:Resource)
# ("banana", rdf:type, rdfs:Resource)
# ("The WhatToMake Individuals Ontology contains the invididual recipes and food items used in those recipes that are available in the system. These individuals are defined using classes and properties that are defined in the WhatToMake Base Ontology."^^xsd:string, rdf:type, rdfs:Resource)
# (ind:BeefNilaga, wtm:serves, "5"^^xsd:nonNegativeInteger)
# (wtm:hasCookingTemperature, rdf:type, rdf:Property)
# (wtm:Flavor, rdf:type, rdfs:Resource)
# ("6"^^xsd:integer, rdf:type, rdfs:Resource)
# (ind:Walnut, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# (wtm:isRecommendedForMeal, rdf:type, rdf:Property)
# (wtm:hasCookTime, rdfs:subPropertyOf, wtm:hasCookTime)
# (ind:Cilantro, wtm:hasGlycemicIndex, "false"^^xsd:boolean)
# ("kamut flour", rdf:type, rdfs:Resource)
# ("Dictionary.com, \"cane sugar.\" [Online]. Available: https://www.dictionary.com/browse/cane-sugar. [Accessed Nov. 10, 2018]", rdf:type, rdfs:Resource)
# ("https://www.allrecipes.com/recipe/241524/flourless-coconut-and-almond-cake/?internalSource=hub%20recipe&referringContentType=Search", rdf:type, rdfs:Resource)
# ("minute", rdf:type, rdfs:Resource)
# ("\"Paprika ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/paprika. [Accessed: 26-Oct-2018].", rdf:type, rdfs:Resource)
# (ind:Tomato, wtm:hasGlycemicIndex, "30"^^xsd:integer)
# ("Myrecipes, \"Pot Roast 101,\" 2018. [Online]. Available: https://www.myrecipes.com/quick-and-easy/how-to-cook-pot-roast. [Accessed Oct. 18, 2018]", rdf:type, rdfs:Resource)
# (wtm:hasCookingTemperature, rdfs:subPropertyOf, wtm:hasCookingTemperature)
# (ind:Lamb, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# (<http://purl.org/heals/food/>, rdf:type, rdfs:Resource)
# ("375"^^xsd:integer, rdf:type, rdfs:Resource)
# (ind:Cheese, wtm:hasGlycemicIndex, "false"^^xsd:boolean)
# ("crunchy", rdf:type, rdfs:Resource)
# ("tart", rdf:type, rdfs:Resource)
# (ind:BraisedBalsamicChicken, rdf:type, rdfs:Resource)
# (ind:Salt, rdf:type, rdfs:Resource)
# (ind:Garlic, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# (ind:BakersYeast, rdf:type, rdfs:Resource)
# ("dried cranberry", rdf:type, rdfs:Resource)
# (wtm:forbids, rdf:type, rdf:Property)
# ("a hard italian bread made from almonds", rdf:type, rdfs:Resource)
# (ind:WhiteVinegar, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# (ind:Blueberry, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# ("baker's yeast", rdf:type, rdfs:Resource)
# (ind:BlackPeppercorn, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# (wtm:hasCookTime, rdf:type, rdf:Property)
# (ind:TapiocaFlour, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# ("English Oxford Living Dictionaries, \"baked,\" 2018. [Online]. Available: https://en.oxforddictionaries.com/definition/baked. [Accessed Oct. 18, 2018]", rdf:type, rdfs:Resource)
# (ind:Tomato, rdf:type, rdfs:Resource)
# ("Allrecipes.com, \"Whole Grain Banana Pancakes,\" 2010. [Online]. Available: https://www.allrecipes.com/recipe/231392/whole-grain-banana-pancakes/?internalSource=hub%20recipe&referringContentType=Search&clickId=cardslot%201. [Accessed Nov.9, 2018]", rdf:type, rdfs:Resource)
# ("Wikipedia, \"Vanilla extract.\" [Online]. Available: https://en.wikipedia.org/wiki/Vanilla_extract. [Accessed: 1-Nov-2018]", rdf:type, rdfs:Resource)
# ("baked foods produced from dough made of flour, water, salt and other optional ingredients, and leavened by yeast or other leavening agents", rdf:type, rdfs:Resource)
# (ind:Coconut, wtm:hasGlycemicIndex, "35"^^xsd:integer)
# (<https://www.omg.org/techprocess/ab/SpecificationMetadata/copyright>, rdfs:subPropertyOf, <https://www.omg.org/techprocess/ab/SpecificationMetadata/copyright>)
# (ind:KamutFlour, wtm:hasGluten, "1"^^xsd:integer)
# (ind:Celery, wtm:hasGlycemicIndex, "15"^^xsd:integer)
# ("\"Celery ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/celery. [Accessed: 26-Oct-2018].", rdf:type, rdfs:Resource)
# (ind:PumpkinSeed, wtm:hasGlycemicIndex, "10"^^xsd:integer)
# (ind:BalsamicVinegar, wtm:hasGlycemicIndex, "5"^^xsd:integer)
# ("Dictionary.com, \"mayonnaise.\" [Online]. Available: https://www.dictionary.com/browse/mayonnaise. [Accessed Nov. 10, 2018]", rdf:type, rdfs:Resource)
# ("honey", rdf:type, rdfs:Resource)
# ("thai chicken", rdf:type, rdfs:Resource)
# (ind:Water, rdf:type, rdfs:Resource)
# (rdfs:label, rdfs:subPropertyOf, rdfs:label)
# (wtm:Lunch, rdf:type, rdfs:Resource)
# ("https://tw.rpi.edu/web/Courses/Ontologies/2018/Project2/maintenance", rdf:type, rdfs:Resource)
# (<http://purl.obolibrary.org/obo/FOODON_03400676>, rdf:type, rdfs:Resource)
# (ind:CaneSugar, rdf:type, rdfs:Resource)
# (ind:GreenOnion, wtm:hasGlycemicIndex, "15"^^xsd:integer)
# ("oat", rdf:type, rdfs:Resource)
# ("https://www.allrecipes.com/recipe/231392/whole-grain-banana-pancakes/?internalSource=hub%20recipe&referringContentType=Search&clickId=cardslot%201", rdf:type, rdfs:Resource)
# (ind:Chicken, rdf:type, rdfs:Resource)
# ("30"^^xsd:integer, rdf:type, rdfs:Resource)
# (ind:Oat, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# ("suggestive of smoke especially in flavor or odor", rdf:type, rdfs:Resource)
# ("a thick dressing of egg yolks, vinegar or lemon juice, oil, and seasonings, used for salads, sandwiches,vegetable dishes, etc", rdf:type, rdfs:Resource)
# ("braised balsamic chicken", rdf:type, rdfs:Resource)
# (ind:CornSyrup, rdf:type, rdfs:Resource)
# (owl:imports, rdfs:subPropertyOf, owl:imports)
# (ind:Gooey, rdf:type, rdfs:Resource)
# (ind:SoySauce, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# (wtm:isRecommendedForCourse, rdf:type, rdf:Property)
# (ind:BeefBouillon, rdf:type, rdfs:Resource)
# ("fahrenheit", rdf:type, rdfs:Resource)
# ("a crystalline compound NaCl that consists of sodium chloride, is abundant in nature, and is used especially to season or preserve food or in industry", rdf:type, rdfs:Resource)
# ("45"^^xsd:integer, rdf:type, rdfs:Resource)
# (<http://purl.obolibrary.org/obo/FOODON_03400681>, rdf:type, rdfs:Resource)
# ("the pod or the enclosed edible seed of the plant, Arachis hypogaea, of the legume family: the pod is forced underground in growing, where it ripens", rdf:type, rdfs:Resource)
# (dcterms:description, rdfs:subPropertyOf, dcterms:description)
# (ind:Butter, rdf:type, rdfs:Resource)
# ("\"pumpkin seed - Dictionary Definition,\" Vocabulary.com. [Online]. Available: https://www.vocabulary.com/dictionary/pumpkin seed. [Accessed: 12-Oct-2018].", rdf:type, rdfs:Resource)
# ("https://www.allrecipes.com/recipe/10549/best-brownies/?internalSource=staff%20pick&referringId=838&referringContentType=Recipe%20Hub", rdf:type, rdfs:Resource)
# ("40"^^xsd:nonNegativeInteger, rdf:type, rdfs:Resource)
# ("vegetable oil", rdf:type, rdfs:Resource)
# ("coconut", rdf:type, rdfs:Resource)
# (ind:SaucyShepherdPie, rdf:type, rdfs:Resource)
# ("the roundish reproductive body produced by a female chicken", rdf:type, rdfs:Resource)
# (wtm:forbids, rdfs:subPropertyOf, wtm:forbids)
# ("the flesh of an adult domestic bovine used as food", rdf:type, rdfs:Resource)
# ("whole wheat flour", rdf:type, rdfs:Resource)
# ("1"^^xsd:integer, rdf:type, rdfs:Resource)
# (ind:Rosemary, rdf:type, rdfs:Resource)
# (ind:CocoaPowder, rdf:type, rdfs:Resource)
# (owl:versionIRI, rdfs:subPropertyOf, owl:versionIRI)
# (ind:OliveOil, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# ("mayonnaise", rdf:type, rdfs:Resource)
# ("cane sugar", rdf:type, rdfs:Resource)
# ("https://www.allrecipes.com/recipe/16862/thai-chicken/?internalSource=hub%20recipe&referringContentType=Search", rdf:type, rdfs:Resource)
# ("40"^^xsd:integer, rdf:type, rdfs:Resource)
# ("brown sugar", rdf:type, rdfs:Resource)
# ("Wiktionary, \"chicken tender,\" Dec. 2017. [Online]. Available: https://en.wiktionary.org/wiki/chicken_tender. [Accessed Oct. 18, 2018]", rdf:type, rdfs:Resource)
# ("the furrowed nut of any of a genus (Juglans of the family Juglandaceae, the walnut family) of deciduous trees", rdf:type, rdfs:Resource)
# (ind:Tarragon, wtm:hasGlycemicIndex, "5"^^xsd:integer)
# ("Baking Bites, \"What is Gluten Free Flour?\"[Online]. Available: http://bakingbites.com/2013/01/what-is-gluten-free-flour/. [Accessed Nov. 1, 2018]", rdf:type, rdfs:Resource)
# (ind:Oregano, rdf:type, rdfs:Resource)
# ("This definition refers to the nuts of the plant as used as an ingredient in a recipe.", rdf:type, rdfs:Resource)
# (<http://purl.obolibrary.org/obo/FOODON_03400674>, rdf:type, rdfs:Resource)
# ("tapioca flour", rdf:type, rdfs:Resource)
# (skos:scopeNote, rdf:type, rdf:Property)
# (<http://purl.obolibrary.org/obo/FOODON_03400688>, rdf:type, rdfs:Resource)
# (ind:Greasy, rdf:type, rdfs:Resource)
# ("http://opensource.org/licenses/MIT"^^xsd:anyURI, rdf:type, rdfs:Resource)
# (ind:Thyme, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# (wtm:serves, rdfs:subPropertyOf, wtm:serves)
# ("\"Nutty,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/nutty. [Accessed: 12-Oct-2018].", rdf:type, rdfs:Resource)
# (ind:GoldenKamutBread, wtm:serves, "true"^^xsd:boolean)
# (<http://purl.obolibrary.org/obo/FOODON_03400689>, rdf:type, rdfs:Resource)
# ("kamut", rdf:type, rdfs:Resource)
# ("45"^^xsd:nonNegativeInteger, rdf:type, rdfs:Resource)
# (ind:PumpkinSeed, rdf:type, rdfs:Resource)
# (<http://purl.obolibrary.org/obo/FOODON_03400673>, rdf:type, rdfs:Resource)
# (ind:Peanut, rdf:type, rdfs:Resource)
# ("a bread made from kamut", rdf:type, rdfs:Resource)
# (ind:GreenOnion, rdf:type, rdfs:Resource)
# ("vanilla extract", rdf:type, rdfs:Resource)
# (ind:Parsley, wtm:hasGlycemicIndex, "5"^^xsd:integer)
# ("a product consisting of finely milled wheat", rdf:type, rdfs:Resource)
# (wtm:Breakfast, rdf:type, rdfs:Resource)
# (rdf:type, rdfs:subPropertyOf, rdf:type)
# (ind:GlutenFreeCoconutCake, wtm:hasCookTime, "60"^^xsd:nonNegativeInteger)
# ("paprika", rdf:type, rdfs:Resource)
# ("moist", rdf:type, rdfs:Resource)
# ("any of several brassicas of European origin especially a leafy garden plant with a short stem and a dense globular head of usually green leaves that is used as a vegetable", rdf:type, rdfs:Resource)
# (ind:BakingPowder, wtm:hasGlycemicIndex, "false"^^xsd:boolean)
# ("\"Cabbage ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/cabbage. [Accessed: 26-Oct-2018].", rdf:type, rdfs:Resource)
# ("blueberry", rdf:type, rdfs:Resource)
# ("https://www.allrecipes.com/recipe/237655/gluten-free-coconut-cake/?internalSource=hub%20recipe&referringContentType=Search&clickId=cardslot%201", rdf:type, rdfs:Resource)
# ("\"Whole Wheat Flour ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/whole wheat flour. [Accessed: 26-Oct-2018].", rdf:type, rdfs:Resource)
# ("tarragon", rdf:type, rdfs:Resource)
# (ind:VanillaExtract, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# ("90"^^xsd:integer, rdf:type, rdfs:Resource)
# ("a stock made with chicken", rdf:type, rdfs:Resource)
# ("flours that are made of non-gluten containing products", rdf:type, rdfs:Resource)
# ("black pepper", rdf:type, rdfs:Resource)
# ("\"Salt,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/salt. [Accessed: 13-Oct-2018].", rdf:type, rdfs:Resource)
# (ind:AllPurposeFlour, wtm:hasGluten, "1"^^xsd:integer)
# ("white sugar", rdf:type, rdfs:Resource)
# ("https://www.foxyfolksy.com/nilagang-baka-filipino-beef-soup-vegetables/", rdf:type, rdfs:Resource)
# ("resembling cream (as in color, texture, or taste)", rdf:type, rdfs:Resource)
# (ind:Cilantro, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# ("salty", rdf:type, rdfs:Resource)
# ("https://www.allrecipes.com/recipe/6687/banana-bread/?internalSource=hub%20recipe&referringContentType=Search", rdf:type, rdfs:Resource)
# ("a solid emulsion of fat globules, air, and water made by churning milk or cream and used as food", rdf:type, rdfs:Resource)
# (ind:Walnut, wtm:hasGlycemicIndex, "15"^^xsd:integer)
# (wtm:substitutesFor, rdfs:subPropertyOf, wtm:substitutesFor)
# ("Allrecipes.com, \"Gluten-Free Coconut Cake,\" 2010. [Online]. Available: https://www.allrecipes.com/recipe/237655/gluten-free-coconut-cake/?internalSource=hub%20recipe&referringContentType=Search&clickId=cardslot%201. [Accessed Nov.9, 2018]", rdf:type, rdfs:Resource)
# ("a cut of beef and is part of the sub primal cut known as the chuck", rdf:type, rdfs:Resource)
# ("starch made from corn and used in foods as a thickening agent, in making corn syrup and sugars, and in the manufacture of adhesives and sizes for paper and textiles", rdf:type, rdfs:Resource)
# (ind:WholeWheatFlour, wtm:hasGluten, "1"^^xsd:integer)
# ("Allrecipes.com, \"Smothered Chicken Breasts,\" 2010. [Online]. Available: https://www.allrecipes.com/recipe/222607/smothered-chicken-breasts/?internalSource=hub%20recipe&referringContentType=Search. [Accessed Nov.9, 2018]", rdf:type, rdfs:Resource)
# ("an oil of plant origin", rdf:type, rdfs:Resource)
# ("What to Make Individuals", rdf:type, rdfs:Resource)
# (ind:Cheese, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# ("the dried or fresh leaves of a basil used especially as a seasoning", rdf:type, rdfs:Resource)
# (ind:Brownies, rdf:type, rdfs:Resource)
# ("relating to, conforming to, or having the international thermometric scale on which the interval between the triple point of water and the boiling point of water is divided into 99.99 degrees with 0.01° representing the triple point and 100° the boiling point", rdf:type, rdfs:Resource)
# ("a small widely cultivated perennial artemisia (Artemisia dracunculus) having aromatic narrow usually entire leaves, its leaves used as a seasoning", rdf:type, rdfs:Resource)
# ("having the consistency of mush", rdf:type, rdfs:Resource)
# ("a usually mild red condiment consisting of the dried finely ground pods of various sweet peppers", rdf:type, rdfs:Resource)
# ("a type of bread made from mashed bananas", rdf:type, rdfs:Resource)
# ("prepared mustard with visible mustard seeds", rdf:type, rdfs:Resource)
# ("a pancake made primarily from kamut", rdf:type, rdfs:Resource)
# ("https://www.allrecipes.com/recipe/15735/fruited-curry-chicken-salad/?internalSource=hub%20recipe&referringContentType=Search", rdf:type, rdfs:Resource)
# (ind:Moist, rdf:type, rdfs:Resource)
# (ind:BalsamicVinegar, rdf:type, rdfs:Resource)
# ("Dictionary.com, \"sesame oil.\" [Online]. Available: https://www.dictionary.com/browse/sesame-oil. [Accessed Nov. 10, 2018]", rdf:type, rdfs:Resource)
# (ind:Banana, rdf:type, rdfs:Resource)
# (ind:GreenPepper, rdf:type, rdfs:Resource)
# (ind:VegetableOil, wtm:hasGlycemicIndex, "false"^^xsd:boolean)
# ("crisp, brittle", rdf:type, rdfs:Resource)
# (wtm:dislikes, rdf:type, rdf:Property)
# (ind:Lamb, rdf:type, rdfs:Resource)
# ("a vegetable oil derived from a variety of rapeseed that is low in erucic acid", rdf:type, rdfs:Resource)
# ("kingarthurflour.com, \"GOLDEN KAMUT BREAD. [Online]. Available: https://www.kingarthurflour.com/recipes/golden-kamut-bread-recipe. [Accessed Nov.9, 2018]", rdf:type, rdfs:Resource)
# ("minced red meat cooked in a gravy or sauce with onions and sometimes other vegetables, such as peas, celery or carrots, and topped with a layer of mashed potato before it is baked", rdf:type, rdfs:Resource)
# ("\"Fahrenheit,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/Fahrenheit. [Accessed: 12-Oct-2018].", rdf:type, rdfs:Resource)
# (ind:Salty, rdf:type, rdfs:Resource)
# ("\"Oregano,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/oregano [Accessed: 1-Nov-2018]", rdf:type, rdfs:Resource)
# ("a powder used as a leavening agent in making baked goods (such as quick breads) that typically consists of sodium bicarbonate, an acidic substance (such as cream of tartar), and starch or flour", rdf:type, rdfs:Resource)
# (<http://purl.obolibrary.org/obo/FOODON_03400764>, rdf:type, rdfs:Resource)
# (dcterms:modified, rdf:type, rdf:Property)
# ("\"Tarragon ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/tarragon. [Accessed: 26-Oct-2018].", rdf:type, rdfs:Resource)
# ("cornstarch", rdf:type, rdfs:Resource)
# (ind:CanolaOil, wtm:hasGlycemicIndex, "false"^^xsd:boolean)
# ("A temperature scale that is used in recipes", rdf:type, rdfs:Resource)
# (ind:ChickenBroth, wtm:hasGlycemicIndex, "false"^^xsd:boolean)
# ("Kevin Blissett", rdf:type, rdfs:Resource)
# (ind:Pecan, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# ("agreeably sharp or acid to the taste", rdf:type, rdfs:Resource)
# (wtm:serves, rdf:type, rdf:Property)
# (owl:priorVersion, rdfs:subPropertyOf, owl:priorVersion)
# (dcterms:source, rdfs:subPropertyOf, dcterms:source)
# (wtm:TemperatureMeasurement, rdf:type, rdfs:Resource)
# ("thyme", rdf:type, rdfs:Resource)
# ("sesame oil", rdf:type, rdfs:Resource)
# ("pumpkin seed", rdf:type, rdfs:Resource)
# ("value of time", rdf:type, rdfs:Resource)
# (rdf:type, rdf:type, rdf:Property)
# (ind:Clove, wtm:hasGlycemicIndex, "5"^^xsd:integer)
# (ind:ChuckRoast, wtm:hasGlycemicIndex, "false"^^xsd:boolean)
# ("a pale yellow to yellowish-green nondrying oil that is obtained from olives, is high in monounsaturated fat, and is used chiefly as a salad oil and in cooking", rdf:type, rdfs:Resource)
# ("baked chicken tender", rdf:type, rdfs:Resource)
# ("almond biscotti", rdf:type, rdfs:Resource)
# (ind:SesameOil, wtm:hasGlycemicIndex, "false"^^xsd:boolean)
# ("the measured or measurable period during which an action, process, or condition exists or continues", rdf:type, rdfs:Resource)
# ("slightly or moderately wet", rdf:type, rdfs:Resource)
# ("chuck roast", rdf:type, rdfs:Resource)
# (skos:definition, rdf:type, rdf:Property)
# (ind:Walnut, rdf:type, rdfs:Resource)
# ("slow-cooked beef with carrots, potatoes, or other vegetables added partway through cooking", rdf:type, rdfs:Resource)
# ("\"Sugar,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/sugar. [Accessed: 1-Nov-2018]", rdf:type, rdfs:Resource)
# ("Wikipedia, \"Dried cranberry.\" [Online]. Available: https://en.wikipedia.org/wiki/Dried_cranberry. [Accessed: Nov. 10, 2018]", rdf:type, rdfs:Resource)
# (<http://purl.org/heals/ingredient/>, rdf:type, rdfs:Resource)
# ("a white crystalline compound, NaHCO3, chemically known as sodium bicarbonate, that is used especially in beverages and as a leavening agent to make baked goods", rdf:type, rdfs:Resource)
# ("Kamut, \"The grain,\" 2018. [Online]. Available: https://www.kamut.com/en/discover/the-grain. [Accessed Oct. 20, 2018]", rdf:type, rdfs:Resource)
# ("greasy", rdf:type, rdfs:Resource)
# ("having the quality, flavor, or fragrance of spice", rdf:type, rdfs:Resource)
# (wtm:hasIngredient, rdf:type, rdf:Property)
# ("\"Gooey,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/gooey. [Accessed: 18-Oct-2018].", rdf:type, rdfs:Resource)
# ("\"Chicken,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/chicken. [Accessed: 13-Oct-2018].", rdf:type, rdfs:Resource)
# (ind:BakingSoda, wtm:hasGlycemicIndex, "false"^^xsd:boolean)
# (ind:Pecan, wtm:hasGlycemicIndex, "15"^^xsd:integer)
# ("a European biennial herb of the carrot family widely grown for its finely dissected curly or flat leaves which are used as an herb or garnish", rdf:type, rdfs:Resource)
# (ind:BeefStew, wtm:serves, "10"^^xsd:nonNegativeInteger)
# (ind:Basil, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# (ind:CoconutMilk, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# (wtm:hasGlycemicIndex, rdf:type, rdf:Property)
# ("relating or conforming to a thermometric scale on which under standard atmospheric pressure the boiling point of water is at 212 degrees above the zero of the scale, the freezing point is at 32 degrees above zero, and the zero point approximates the temperature produced by mixing equal quantities by weight of snow and common salt", rdf:type, rdfs:Resource)
# (ind:Fahrenheit, rdf:type, rdfs:Resource)
# ("Wikipedia, \"Gluten.\" [Online]. Available: https://en.wikipedia.org/wiki/Gluten. [Accessed: Oct. 25, 2018] ", rdf:type, rdfs:Resource)
# (ind:ChickenEgg, rdf:type, rdfs:Resource)
# (ind:OliveOil, rdf:type, rdfs:Resource)
# ("clove", rdf:type, rdfs:Resource)
# ("beef bouillon", rdf:type, rdfs:Resource)
# (wtm:hasIngredient, rdfs:subPropertyOf, wtm:hasIngredient)
# ("canola oil", rdf:type, rdfs:Resource)
# ("10"^^xsd:nonNegativeInteger, rdf:type, rdfs:Resource)
# ("a vinegar made from fermented apple juice", rdf:type, rdfs:Resource)
# ("https://www.allrecipes.com/recipe/6771/simple-white-bread/?internalSource=hub%20recipe&referringContentType=Search&clickId=cardslot%2011", rdf:type, rdfs:Resource)
# ("a memeber of the nightshade family widely cultivated for its edible starchy tuber", rdf:type, rdfs:Resource)
# (prov:wasDerivedFrom, rdf:type, rdf:Property)
# (ind:DriedCranberry, wtm:hasGlycemicIndex, "30"^^xsd:integer)
# ("\"Tart,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/tart. [Accessed: 18-Oct-2018].", rdf:type, rdfs:Resource)
# (ind:AppleCiderVinegar, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# (ind:AlmondMeal, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# ("syrup prepared from corn", rdf:type, rdfs:Resource)
# (ind:Clove, rdf:type, rdfs:Resource)
# ("creamy", rdf:type, rdfs:Resource)
# ("the edible seed of a pumpkin", rdf:type, rdfs:Resource)
# ("a Mediterranean-inspired chicken recipe by cooking the chicken with both wet and dry heats, signatured by the balsamic vinegar in the recipe", rdf:type, rdfs:Resource)
# (dcterms:description, rdf:type, rdf:Property)
# (ind:ChickenSalad, rdf:type, rdfs:Resource)
# (ind:AlmondBiscotti, rdf:type, rdfs:Resource)
# (ind:GlutenFreeFlour, rdf:type, rdfs:Resource)
# (ind:WholeGrainMustard, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# ("Allrecipes.com, \"Flourless Coconut and Almond Cake,\" 2010. [Online]. Available: https://www.allrecipes.com/recipe/241524/flourless-coconut-and-almond-cake/?internalSource=hub%20recipe&referringContentType=Search. [Accessed Nov.9, 2018]", rdf:type, rdfs:Resource)
# (ind:Nutty, rdf:type, rdfs:Resource)
# ("whole grain banana pancake", rdf:type, rdfs:Resource)
# (ind:Thyme, rdf:type, rdfs:Resource)
# ("20"^^xsd:integer, rdf:type, rdfs:Resource)
# (<http://purl.obolibrary.org/obo/FOODON_03400666>, rdf:type, rdfs:Resource)
# (dcterms:license, rdfs:subPropertyOf, dcterms:license)
# ("Wikipedia, \"Braising.\" [Online]. Available: https://en.wikipedia.org/wiki/Braising. [Accessed: 1-Nov-2018]", rdf:type, rdfs:Resource)
# (ind:CanolaOil, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# (ind:Carrot, rdf:type, rdfs:Resource)
# (ind:Mushy, rdf:type, rdfs:Resource)
# ("A portion of chicken", rdf:type, rdfs:Resource)
# (ind:Coconut, rdf:type, rdfs:Resource)
# (ind:Potato, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# ("pear-shaped fruit of a West Indian annual vine (Sechium edule) of the gourd family that is widely cultivated as a vegetable", rdf:type, rdfs:Resource)
# (ind:Beef, rdf:type, rdfs:Resource)
# ("WhatToMake", rdf:type, rdfs:Resource)
# ("a sweet crystallizable material that consists wholly or essentially of sucrose, is colorless or white when pure tending to brown when less refined, is obtained commercially from sugarcane or sugar beet and less extensively from sorghum, maples, and palms, and is important as a source of dietary carbohydrate and as a sweetener and preservative of other foods", rdf:type, rdfs:Resource)
# (ind:BeefStew, rdf:type, rdfs:Resource)
# ("tomato", rdf:type, rdfs:Resource)
# (ind:CornedBeef, rdf:type, rdfs:Resource)
# (ind:ChayoteSquash, wtm:hasGlycemicIndex, "50"^^xsd:integer)
# (ind:KamutPancake, rdf:type, rdfs:Resource)
# ("Dictionary.com, \"green pepper.\" [Online]. Available: https://www.dictionary.com/browse/green-pepper. [Accessed Nov. 10, 2018]", rdf:type, rdfs:Resource)
# (ind:SesameOil, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# (ind:Parsley, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# (ind:KamutMuffin, rdf:type, rdfs:Resource)
# (<http://purl.obolibrary.org/obo/FOODON_03400775>, rdf:type, rdfs:Resource)
# (ind:WholeGrainBananaPancake, wtm:hasCookTime, "20"^^xsd:nonNegativeInteger)
# ("white bread", rdf:type, rdfs:Resource)
# ("4"^^xsd:integer, rdf:type, rdfs:Resource)
# ("a banana blueberry muffin made with almond flour", rdf:type, rdfs:Resource)
# ("butter", rdf:type, rdfs:Resource)
# (ind:BakedChickenTender, wtm:hasCookTime, "45"^^xsd:nonNegativeInteger)
# ("0"^^xsd:nonNegativeInteger, rdf:type, rdfs:Resource)
# (ind:VegetableOil, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# (ind:LemonJuice, wtm:hasGlycemicIndex, "20"^^xsd:integer)
# ("\"Bitter,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/bitter. [Accessed: 18-Oct-2018].", rdf:type, rdfs:Resource)
# (skos:editorialNote, rdfs:subPropertyOf, skos:editorialNote)
# (ind:Kamut, rdf:type, rdfs:Resource)
# (ind:Cheese, rdf:type, rdfs:Resource)
# ("\"Beef,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/beef. [Accessed: 13-Oct-2018].", rdf:type, rdfs:Resource)
# ("a dish made from chicken breast, topped with bacon, caramelized onions, and zippy shredded cheese", rdf:type, rdfs:Resource)
# (ind:BakedChickenTender, rdf:type, rdfs:Resource)
# ("basil", rdf:type, rdfs:Resource)
# (<http://purl.obolibrary.org/obo/FOODON_03400774>, rdf:type, rdfs:Resource)
# (ind:AlmondBiscotti, wtm:serves, "15"^^xsd:nonNegativeInteger)
# (ind:Almond, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# (ind:GrilledChickenKabob, rdf:type, rdfs:Resource)
# (ind:Rosemary, wtm:hasGlycemicIndex, "5"^^xsd:integer)
# ("brownies", rdf:type, rdfs:Resource)
# ("70"^^xsd:nonNegativeInteger, rdf:type, rdfs:Resource)
# ("Only used to refer to the egg of a chicken. Other types of eggs will appear under separate labels in the ontology.", rdf:type, rdfs:Resource)
# ...
# ("\"Baking soda,\" the free dictionary. [Online]. Available: https://www.thefreedictionary.com/baking+soda [Accessed: 26-Oct-2018].", rdf:type, rdfs:Resource)
# ("Dictionary.com, \"egg.\" [Online]. Available: https://www.dictionary.com/browse/egg. [Accessed Oct. 5, 2018]", rdf:type, rdfs:Resource)
# (ind:DriedCranberry, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# (ind:Hour, rdf:type, rdfs:Resource)
# ("Wikipedia, \"Coconut cake.\" [Online]. Available: https://en.wikipedia.org/wiki/Coconut_cake. [Accessed: Oct. 25, 2018]", rdf:type, rdfs:Resource)
# (ind:ChickenBroth, wtm:hasGluten, "1"^^xsd:integer)
# (ind:WhiteSugar, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# (wtm:Dessert, rdf:type, rdfs:Resource)
# (ind:Chicken, wtm:hasGlycemicIndex, "false"^^xsd:boolean)
# ("baking powder", rdf:type, rdfs:Resource)
# ("15"^^xsd:integer, rdf:type, rdfs:Resource)
# ("\"Brownie,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/brownie. [Accessed: 1-Nov-2018]", rdf:type, rdfs:Resource)
# (ind:Basil, rdf:type, rdfs:Resource)
# (skos:editorialNote, rdf:type, rdf:Property)
# ("sweet", rdf:type, rdfs:Resource)
# (dcterms:publisher, rdf:type, rdf:Property)
# (ind:BrownSugar, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# (ind:Celery, rdf:type, rdfs:Resource)
# ("a dried berry of the black pepper", rdf:type, rdfs:Resource)
# ("an elongated usually tapering tropical fruit with soft pulpy flesh enclosed in a soft usually yellow rind", rdf:type, rdfs:Resource)
# (ind:Paprika, rdf:type, rdfs:Resource)
# ("the aromatic flower buds of a tree in the family Myrtaceae", rdf:type, rdfs:Resource)
# ("a muffin made primarily from kamut", rdf:type, rdfs:Resource)
# (<http://purl.obolibrary.org/obo/FOODON_03400671>, rdf:type, rdfs:Resource)
# ("soft sugar whose crystals are covered by a film of refined dark syrup", rdf:type, rdfs:Resource)
# ("chicken broth", rdf:type, rdfs:Resource)
# ("a viscid or sticky substance", rdf:type, rdfs:Resource)
# (ind:AppleCiderVinegar, rdf:type, rdfs:Resource)
# ("peanut", rdf:type, rdfs:Resource)
# ("140"^^xsd:integer, rdf:type, rdfs:Resource)
# ("an ingredient that can be combined with water to substitute for beef stock", rdf:type, rdfs:Resource)
# (wtm:MeatFromChicken, rdf:type, rdfs:Resource)
# (ind:Tart, rdf:type, rdfs:Resource)
# (ind:BeefNilaga, rdf:type, rdfs:Resource)
# ("balsamic vinegar", rdf:type, rdfs:Resource)
# ("pot roast with vegetables", rdf:type, rdfs:Resource)
# (ind:Honey, rdf:type, rdfs:Resource)
# (ind:TapiocaFlour, rdf:type, rdfs:Resource)
# ("\"Peppercorn ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/peppercorn. [Accessed: 26-Oct-2018].", rdf:type, rdfs:Resource)
# ("\"Lamb,\" WIKIPEDIA [Online]. Available: https://en.wikipedia.org/wiki/Lamb [Accessed: 26-Oct-2018].", rdf:type, rdfs:Resource)
# ("green pepper", rdf:type, rdfs:Resource)
# ("\"Potato,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/potato. [Accessed: 13-Oct-2018].", rdf:type, rdfs:Resource)
# (skos:altLabel, rdf:type, rdf:Property)
# ("\"Salty,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/salty. [Accessed: 18-Oct-2018].", rdf:type, rdfs:Resource)
# (<http://purl.obolibrary.org/obo/FOODON_03400675>, rdf:type, rdfs:Resource)
# (wtm:hasGluten, rdf:type, rdf:Property)
# (skos:definition, rdfs:subPropertyOf, skos:definition)
# (ind:Salt, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# (ind:WholeWheatFlour, wtm:hasGlycemicIndex, "40"^^xsd:integer)
# ("\"Onion ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/onion. [Accessed: 26-Oct-2018].", rdf:type, rdfs:Resource)
# (ind:BakersYeast, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# (owl:priorVersion, rdf:type, rdf:Property)
# (ind:BananaBread, wtm:serves, "10"^^xsd:nonNegativeInteger)
# (<http://purl.obolibrary.org/obo/FOODON_03400686>, rdf:type, rdfs:Resource)
# (ind:WholeWheatFlour, rdf:type, rdfs:Resource)
# (ind:Tomato, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# ("a biennial herb with a usually orange spindle-shaped edible root", rdf:type, rdfs:Resource)
# ("flourless coconut and almond cake", rdf:type, rdfs:Resource)
# (dcterms:references, rdf:type, rdf:Property)
# ("a culinary dish consisting of diced or chopped meat, potatoes and spices that are mixed together and cooked by themselves or with other ingredients such as onions", rdf:type, rdfs:Resource)
# (<http://purl.obolibrary.org/obo/FOODON_03400663>, rdf:type, rdfs:Resource)
# ("\"Basil,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/basil [Accessed: 1-Nov-2018]", rdf:type, rdfs:Resource)
# (ind:GoldenKamutBread, rdf:type, rdfs:Resource)
# ("185"^^xsd:integer, rdf:type, rdfs:Resource)
# ("Sanderson Farms, \"Balsamic Braised Chicken Thighs.\" [Online]. Available: http://sandersonfarms.mobi/recipes/balsamic-braised-chicken-thighs/. [Accessed: 1-Nov-2018]", rdf:type, rdfs:Resource)
# ("the mild-flavored, unripe fruit of the bell or sweet pepper, Capsicum annuum grossum, used as a greenvegetable", rdf:type, rdfs:Resource)
# ("spicy", rdf:type, rdfs:Resource)
# (ind:Mayonnaise, wtm:hasGlycemicIndex, "60"^^xsd:integer)
# ("\"Banana ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/banana. [Accessed: 26-Oct-2018].", rdf:type, rdfs:Resource)
# ("the usually large, rounded, edible, pulpy berry of an herb (genus Solanum) of the nightshade family native to South America that is typically red but may be yellow, orange, green, or purplish in color and is eaten raw or cooked as a vegetable", rdf:type, rdfs:Resource)
# ("lamb", rdf:type, rdfs:Resource)
# (ind:ChayoteSquash, rdf:type, rdfs:Resource)
# (ind:SoySauce, rdf:type, rdfs:Resource)
# ("https://www.kingarthurflour.com/recipes/golden-kamut-bread-recipe", rdf:type, rdfs:Resource)
# (ind:Blueberry, rdf:type, rdfs:Resource)
# ("the user with ID 15", rdf:type, rdfs:Resource)
# ("white vinegar", rdf:type, rdfs:Resource)
# (ind:BeefBouillon, wtm:hasGlycemicIndex, "false"^^xsd:boolean)
# ("350"^^xsd:integer, rdf:type, rdfs:Resource)
# (skos:scopeNote, rdfs:subPropertyOf, skos:scopeNote)
# (wtm:Recipe, rdf:type, rdfs:Resource)
# (ind:Bitter, rdf:type, rdfs:Resource)
# ("\"Butter ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/butter. [Accessed: 26-Oct-2018].", rdf:type, rdfs:Resource)
# (wtm:MilkFromCow, rdf:type, rdfs:Resource)
# (ind:CaneSugar, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# (ind:VanillaExtract, wtm:hasGlycemicIndex, "5"^^xsd:integer)
# (ind:ThaiChicken, wtm:hasCookTime, "15"^^xsd:nonNegativeInteger)
# (ind:Butter, wtm:hasGlycemicIndex, "false"^^xsd:boolean)
# ("hour", rdf:type, rdfs:Resource)
# ("http://sandersonfarms.mobi/recipes/balsamic-braised-chicken-thighs/", rdf:type, rdfs:Resource)
# (ind:Garlic, rdf:type, rdfs:Resource)
# ("cocoa powder", rdf:type, rdfs:Resource)
# (owl:versionIRI, rdf:type, rdf:Property)
# (ind:WhiteVinegar, rdf:type, rdfs:Resource)
# (ind:Minute, rdf:type, rdfs:Resource)
# (ind:BlackPeppercorn, rdf:type, rdfs:Resource)
# ("https://www.allrecipes.com/recipe/64513/rosemary-ranch-chicken-kabobs/?internalSource=hub%20recipe&referringContentType=Search", rdf:type, rdfs:Resource)
# ("false"^^xsd:boolean, rdf:type, rdfs:Resource)
# ("a sour liquid consisting of dilute and impure acetic acid", rdf:type, rdfs:Resource)
# (ind:Onion, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# (ind:CocoaPowder, wtm:hasGlycemicIndex, "20"^^xsd:integer)
# ("garlic", rdf:type, rdfs:Resource)
# (ind:CornSyrup, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# ("whole grain mustard", rdf:type, rdfs:Resource)
# ("Dictionary.com, \"blueberry.\" [Online]. Available: https://www.dictionary.com/browse/blueberry. [Accessed Nov. 10, 2018]", rdf:type, rdfs:Resource)
# ("85"^^xsd:nonNegativeInteger, rdf:type, rdfs:Resource)
# (ind:BananaBlueberryAlmondFlourMuffin, rdf:type, rdfs:Resource)
# (ind:BeefBouillon, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# ("mushy", rdf:type, rdfs:Resource)
# ("\"Crunchy,\" Dictionary.com. [Online]. Available: https://www.dictionary.com/browse/crunchy?s=t. [Accessed: 12-Oct-2018].", rdf:type, rdfs:Resource)
# (ind:CanolaOil, rdf:type, rdfs:Resource)
# (<http://purl.obolibrary.org/obo/FOODON_03400756>, rdf:type, rdfs:Resource)
# (skos:altLabel, rdfs:subPropertyOf, skos:altLabel)
# ("Wikipedia, \"Baker's yeast.\" [Online]. Available: https://en.wikipedia.org/wiki/Baker%27s_yeast. [Accessed: Nov. 22, 2018]", rdf:type, rdfs:Resource)
# ("smoky", rdf:type, rdfs:Resource)
# ("30"^^xsd:nonNegativeInteger, rdf:type, rdfs:Resource)
# (wtm:Texture, rdf:type, rdfs:Resource)
# (ind:WhiteBread, rdf:type, rdfs:Resource)
# ("banana blueberry almond flour muffin", rdf:type, rdfs:Resource)
# (<http://purl.obolibrary.org/obo/FOODON_03400744>, rdf:type, rdfs:Resource)
# ("Copyright (c) 2018 Kevin Blissett, Forest Eckhardt, Yarden Ne'eman, Miao Qi", rdf:type, rdfs:Resource)
# ("\"Black Pepper,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/black pepper. [Accessed: 13-Oct-2018].", rdf:type, rdfs:Resource)
# ("3"^^xsd:integer, rdf:type, rdfs:Resource)
# ("beef", rdf:type, rdfs:Resource)
# (ind:Potato, rdf:type, rdfs:Resource)
# (ind:Rosemary, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# (ind:KamutPancake, wtm:hasCookTime, "45"^^xsd:nonNegativeInteger)
# ("Wikipedia, \"Almond meal.\" [Online]. Available:https://en.wikipedia.org/wiki/Almond_meal. [Accessed: Nov. 10, 2018]", rdf:type, rdfs:Resource)
# (ind:CocoaPowder, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# ("a thai dish made with chicken", rdf:type, rdfs:Resource)
# ("Wikipedia, \"Apple cider vinegar.\" [Online]. Available: https://en.wikipedia.org/wiki/Apple_cider_vinegar. [Accessed: Nov. 10, 2018]", rdf:type, rdfs:Resource)
# (ind:Thyme, wtm:hasGlycemicIndex, "5"^^xsd:integer)
# (ind:GrilledChickenKabob, wtm:hasCookTime, "60"^^xsd:nonNegativeInteger)
# ("Wikipedia, \"Shepherd's pie,\" Oct. 2018. [Online]. Available: https://en.wikipedia.org/wiki/Shepherd%27s_pie. [Accessed Oct. 18, 2018]", rdf:type, rdfs:Resource)
# (ind:Oat, wtm:hasGlycemicIndex, "40"^^xsd:integer)
# ("TasteofHome, \"What Is Whole Grain Mustard?,\" 2018. [Online]. Available: https://www.tasteofhome.com/cooking-tips/ask-the-test-kitchen/what-is-whole-grain-mustard-. [Accessed Oct. 27 2018]", rdf:type, rdfs:Resource)
# ("\"Water ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/water. [Accessed: 26-Oct-2018].", rdf:type, rdfs:Resource)
# (ind:Oregano, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# ("beef that has been preserved in salt water", rdf:type, rdfs:Resource)
# (ind:Onion, wtm:hasGlycemicIndex, "15"^^xsd:integer)
# (ind:Oat, rdf:type, rdfs:Resource)
# ("Allrecipes.com, \"Thai Chicken,\" 2010. [Online]. Available: https://www.allrecipes.com/recipe/16862/thai-chicken/?internalSource=hub%20recipe&referringContentType=Search. [Accessed Nov.9, 2018]", rdf:type, rdfs:Resource)
# (ind:SaucyShepherdPie, wtm:serves, "5"^^xsd:nonNegativeInteger)
# (<http://purl.obolibrary.org/obo/FOODON_03400682>, rdf:type, rdfs:Resource)
# ("425"^^xsd:integer, rdf:type, rdfs:Resource)
# ("115"^^xsd:nonNegativeInteger, rdf:type, rdfs:Resource)
# ("Changes to this ontology since the previous version include: update of ontology IRI", rdf:type, rdfs:Resource)
# ("a sweet viscid material elaborated out of the nectar of flowers in the honey sac of various bees", rdf:type, rdfs:Resource)
# ("the liquid that descends from the clouds as rain, forms streams, lakes, and seas, and is a major constituent of all living matter and that when pure is an odorless, tasteless, very slightly compressible liquid oxide of hydrogen H2O which appears bluish in thick layers, freezes at 0° C and boils at 100° C, has a maximum density at 4° C and a high specific heat, is feebly ionized to hydrogen and hydroxyl ions, and is a poor conductor of electricity and a good solvent", rdf:type, rdfs:Resource)
# ("usually freshly squeezed juice of lemons", rdf:type, rdfs:Resource)
# (ind:Chicken, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# ("71"^^xsd:nonNegativeInteger, rdf:type, rdfs:Resource)
# (ind:PumpkinSeed, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# ("5"^^xsd:integer, rdf:type, rdfs:Resource)
# ("vocabulary.com, \"chicken broth.\" [Online]. Available: https://www.vocabulary.com/dictionary/chicken%20broth. [Accessed Nov. 10, 2018]", rdf:type, rdfs:Resource)
# ("Allrecipes.com, \"Simple White Bread,\" 2010. [Online]. Available: https://www.allrecipes.com/recipe/6771/simple-white-bread/?internalSource=hub%20recipe&referringContentType=Search&clickId=cardslot%2011. [Accessed Nov.9, 2018]", rdf:type, rdfs:Resource)
# ("corned beef", rdf:type, rdfs:Resource)
# ("the strong-scented leaves of the coriander plant, used in salads or to flavor and garnish food", rdf:type, rdfs:Resource)
# (ind:FlourlessCoconutAndAlmondCake, rdf:type, rdfs:Resource)
# ("https://www.allrecipes.com/recipe/238606/saucy-shepherds-pie/?internalSource=hub%20recipe&referringContentType=Search", rdf:type, rdfs:Resource)
# ("a fragrant shrubby Mediterranean mint having grayish-green needlelike leaves used as a seasoning", rdf:type, rdfs:Resource)
# (ind:Butter, wtm:hasGluten, "0"^^xsd:nonNegativeInteger)
# (wtm:substitutesFor, rdf:type, rdf:Property)
# ("kingarthurflour.com, \"baking with ancient grains: KAMUT FLOUR.\" [Online]. Available: https://www.kingarthurflour.com/guides/baking-with-ancient-grains/kamut-flour/. [Accessed Nov.9, 2018]", rdf:type, rdfs:Resource)
# (ind:CornedBeefHash, rdf:type, rdfs:Resource)
# ("https://www.allrecipes.com/recipe/238012/banana-blueberry-almond-flour-muffins-gluten-free/?internalSource=hub%20recipe&referringContentType=Search", rdf:type, rdfs:Resource)
# ("a banana pancake made with whole grain", rdf:type, rdfs:Resource)
# ("an aged Italian vinegar made from the must of white grapes", rdf:type, rdfs:Resource)
# ("a tall hickory tree, Carya illinoinensis, of the southern U.S. and Mexico, cultivated for its oval, smooth-shelled, edible nuts", rdf:type, rdfs:Resource)
# ("having a flavor like that of nuts", rdf:type, rdfs:Resource)
# ("a cake made with coconut and almonds which contains no white flour", rdf:type, rdfs:Resource)
# ("2019-04-12"^^xsd:date, rdf:type, rdfs:Resource)
# ("flour made from an ancient grain also known as khorsan wheat", rdf:type, rdfs:Resource)
# ("35"^^xsd:integer, rdf:type, rdfs:Resource)
# ("an ingredient made by partially dehydrating fresh cranberries", rdf:type, rdfs:Resource)
# ("\"Baking powder,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/baking%20powder. [Accessed: 1-Nov-2018]", rdf:type, rdfs:Resource)
# (dcterms:contributor, rdf:type, rdf:Property)
# ("\"Tapioca,\" The Free Dictionary. [Online]. Available: https://www.thefreedictionary.com/Tapioca+flour. [Accessed Nov.9, 2018]", rdf:type, rdfs:Resource)
# (ind:Basil, wtm:hasGlycemicIndex, "5"^^xsd:integer)
# ("user 15", rdf:type, rdfs:Resource)
# (<http://purl.obolibrary.org/obo/FOODON_03400766>, rdf:type, rdfs:Resource)
# (owl:imports, rdf:type, rdf:Property)
# ("the large, hard-shelled seed of the coconut palm, lined with a white edible meat, and containing a milky liquid", rdf:type, rdfs:Resource)
# ("minutes", rdf:type, rdfs:Resource)
# ("\"Brown Surgar,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/brown sugar. [Accessed: 26-Oct-2018].", rdf:type, rdfs:Resource)
# (ind:BananaBread, rdf:type, rdfs:Resource)
# (ind:SmotheredChickenBreast, wtm:hasCookTime, "35"^^xsd:nonNegativeInteger)
# ("EATBYDATE, \"Beef Broth Substitutes,\" 2012. [Online]. Available: https://www.eatbydate.com/substitutions/beef-broth-substitute/. [Accessed Oct. 27, 2018]", rdf:type, rdfs:Resource)
# ("Miao Qi", rdf:type, rdfs:Resource)
# ("celery", rdf:type, rdfs:Resource)
# ("Dictionary.com, \"peanut.\" [Online]. Available: https://www.dictionary.com/browse/peanut. [Accessed Oct. 5, 2018]", rdf:type, rdfs:Resource)
# ("corned beef hash", rdf:type, rdfs:Resource)
# (wtm:isAllergicTo, rdfs:subPropertyOf, wtm:isAllergicTo)
# ("\"Corned beef ,\" Merriam-Webster. [Online]. Available: https://www.merriam-webster.com/dictionary/corned beef. [Accessed: 26-Oct-2018].", rdf:type, rdfs:Resource)
# ("16"^^xsd:integer, rdf:type, rdfs:Resource)

# %% [markdown]
# **Examples of how RDF semantics could aid the chefs in a restaurant.**
#
# RDF semantics could help chefs:
# 1. represent dietary restrictions and preferences. Chefs could use entailment to automatically identify suitable recipes considering customer preferences or dietary restrictions. For instance, if a customer is allergic to gluten, the system could suggest gluten-free alternatives.
# 2. define relationships between ingredients to specify which ingredients can substitute for each other. For example, an RDF triple could assert that "Almond substitutes Pecan". This information can be valuable for chefs when they need to accommodate guests with allergies or preferences by suggesting alternative ingredients in recipes.
# 3. define relationships between recipes and meal categories. For instance, an RDF triple could assert that specific recipe is recommended for lunch. Chefs can then receive suggestions for lunch menu items based on these semantic relationships, improving the menu planning process.

# %% [markdown]
# **Additional classes and properties for WTM vocabulary:**
#
# * *Cuisine Class:*
# WTM.Cuisine - a class representing different cuisines (e.g., Italian, Asian, Mexican).
# * *Difficulty Level Class:*
# WTM.DifficultyLevel - a class representing the difficulty level of a recipe (e.g., easy, intermediate, advanced).
# * *Cooking Technique Class:*
# WTM.CookingTechnique - a class representing specific cooking techniques (e.g., grilling, baking, sauteing).
# * *Special Occasion Property:*
# WTM.isRecommendedForOccasion - a property indicating recipes suitable for special occasions (e.g., holidays, celebrations).
#
# **Additional properties for IND vocabulary:**
#
# * *Organic Property:*
# IND.isOrganic - a property indicating whether an ingredient is organic.
# * *Nutritional Information Property:*
# IND.hasNutritionalInformation - a property linking ingredients to their nutritional information.
# * *Halal or Kosher Property:*
# IND.isHalal and ind.isKosher - properties indicating whether an ingredient is suitable for Halal or Kosher dietary preferences.
